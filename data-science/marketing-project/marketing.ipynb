# %% [markdown]
# # Проект: Маркетинг

# %% [markdown]
# Интернет-магазин собирает историю покупателей, проводит рассылки предложений и
# планирует будущие продажи. Для оптимизации процессов надо выделить пользователей,
# которые готовы совершить покупку в ближайшее время.
#
# Цель:
# Предсказать вероятность покупки в течение 90 дней

# %% [markdown]
# ## Настройка окружения

# %% [markdown]
# ### Импорты

# %%
# %pip install -Uq numpy matplotlib contourpy scikit-learn scipy pandas pyarrow
# %pip install -Uq pandas pandas-stubs
# %pip install -Uq plotly
# %pip install -Uq shap
# %pip install -Uq phik
# %pip install -Uq lightgbm
# %pip install -Uq catboost
# %pip install -Uq optuna

# %pip install -Uq Levenshtein
# Out:
# Note: you may need to restart the kernel to use updated packages.
# Note: you may need to restart the kernel to use updated packages.
# Note: you may need to restart the kernel to use updated packages.
# Note: you may need to restart the kernel to use updated packages.
# Note: you may need to restart the kernel to use updated packages.
# Note: you may need to restart the kernel to use updated packages.

# %%
import matplotlib.pyplot as plt
import pandas as pd

import plotly.express as px
import plotly.graph_objects as go
import optuna # type: ignore
import seaborn as sns
import math

import warnings

from catboost import CatBoostClassifier  # type: ignore
from phik import phik_matrix
from sklearn.impute import SimpleImputer
from sklearn.metrics import (
    mean_squared_error,
    roc_auc_score,
)
from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer

from sklearn.preprocessing import (
    OneHotEncoder,
    StandardScaler,
)

from sklearn.model_selection import (
    train_test_split,
    cross_validate,
)

from sklearn.linear_model import Perceptron
from sklearn.tree import DecisionTreeClassifier

# %% [markdown]
# ### Настройки отображения

# %%
# output settings
warnings.filterwarnings("ignore")

options = {
    "display.max_rows": None,
    "display.max_columns": None,
    "display.float_format": "{:,.2f}".format,
    "display.max_colwidth": None,
}

# Применяем опции через цикл
for option, value in options.items():
    pd.set_option(option, value)

# %% [markdown]
# ### Объявление функций

# %%
def check_size(current_df: pd.DataFrame, original_df: pd.DataFrame):
    print("Количество записей в текущем датасете: {}".format(len(current_df)))
    print("Количество записей в оригинальном датасете: {}".format(len(original_df)))
    print("Процент от начального объема данных: {:.2%}".format(len(current_df) / len(original_df)))

# %%
import os

HOST = "https://code.s3.yandex.net"
HTTP_PREFIX = "http"


# load csv
def load_csv(dataset_path: str, **kwargs):
    # check server request --> relative path --> absolute path --> yandex server request
    path = (
        dataset_path
        if dataset_path.startswith(HTTP_PREFIX)
        else "." + dataset_path if os.path.exists("." + dataset_path)
        else dataset_path if os.path.exists(dataset_path)
        else HOST + dataset_path
    )
    print("Dataset path:", path)
    try:
        return pd.read_csv(filepath_or_buffer=path, **kwargs)
    except Exception as ex:
        print("Could not load csv. Exception:", str(ex))

# %%
def describe_dataset(df):
    """
    Выводит общую информацию и статистику по датасету pandas.

    Параметры:
    - df (pandas.DataFrame): Исходный датасет.
    """
    # 1. Общая информация о датасете
    print("*** Общая информация ***\n")
    print(df.info())
    print("\n")

    # 2. Статистика по количественным данным
    print("*** Статистика по количественным данным ***")
    display(df.describe())
    print("\n")

   # 3. Статистика по категориальным данным
    print("*** Статистика по категориальным данным ***")
    category_cols = df.select_dtypes(include=['object', 'category']).columns
    if len(category_cols) > 0:
        print(df[category_cols].describe())
    else:
        print("Нет категориальных признаков для анализа.")
    print("\n")

    # 4. Информация по колонкам
    print("*** Информация по колонкам ***")
    column_info = pd.DataFrame(
        {
            "type": df.dtypes,
            "na_count": df.isna().sum(),
            "empty_count": (df == "").sum(),
            "unique_count": df.nunique(),
        }
    )
    display(column_info)
    print("\n")

    # 5. Количество дубликатов
    duplicates = df.duplicated().sum()
    print(f"*** Количество дубликатов: {duplicates} ***")
    print("\n")

    # 6. Первые 5 строк датасета
    print("*** Первые 5 строк датасета ***")
    display(df.head())

# %% [markdown]
# ## Загрузка данных

# %% [markdown]
# Проведем первичную (предварительную) загрузку небольшого количества строк данных для каждого датасета, чтобы посмотреть на данные и оценить их

# %%
df_dict = {
    "df_apparel_messages": "apparel-messages.csv",
    "df_apparel_purchases": "apparel-purchases.csv",
    "df_apparel_target_binary": "apparel-target_binary.csv",
    # "df_full_campaign_daily_event_channel": "full_campaign_daily_event_channel.csv",
    # "df_full_campaign_daily_event": "full_campaign_daily_event.csv",
}

for df_name, df_file_name in df_dict.items():
    name = df_name
    print("-" * 10, f"start {name}", "-" * 10, "\n")
    path = ".private/" + df_file_name
    df_name = pd.read_csv(path, nrows=5)
    display(df_name.head())
    display(df_name.dtypes)
    print("-" * 10, f"end {name}", "-" * 10, "\n")
# Out:
# ---------- start df_apparel_messages ----------
#    bulk_campaign_id            client_id  \
# 0              4439  1515915625626736623
# 1              4439  1515915625490086521
# 2              4439  1515915625553578558
# 3              4439  1515915625553578558
# 4              4439  1515915625471518311
#
#                                message_id  event channel        date  \
# 0  1515915625626736623-4439-6283415ac07ea   open   email  2022-05-19
# 1  1515915625490086521-4439-62834150016dd   open   email  2022-05-19
# 2  1515915625553578558-4439-6283415b36b4f   open   email  2022-05-19
# 3  1515915625553578558-4439-6283415b36b4f  click   email  2022-05-19
# 4  1515915625471518311-4439-628341570c133   open   email  2022-05-19
#
#             created_at
# 0  2022-05-19 00:14:20
# 1  2022-05-19 00:39:34
# 2  2022-05-19 00:51:49
# 3  2022-05-19 00:52:20
# 4  2022-05-19 00:56:52
# bulk_campaign_id     int64
# client_id            int64
# message_id          object
# event               object
# channel             object
# date                object
# created_at          object
# dtype: object
# ---------- end df_apparel_messages ----------
#
# ---------- start df_apparel_purchases ----------
#              client_id  quantity    price               category_ids  \
# 0  1515915625468169594         1 1,999.00   ['4', '28', '57', '431']
# 1  1515915625468169594         1 2,499.00   ['4', '28', '57', '431']
# 2  1515915625471138230         1 6,499.00   ['4', '28', '57', '431']
# 3  1515915625471138230         1 4,999.00  ['4', '28', '244', '432']
# 4  1515915625471138230         1 4,999.00   ['4', '28', '49', '413']
#
#          date                              message_id
# 0  2022-05-16  1515915625468169594-4301-627b661e9736d
# 1  2022-05-16  1515915625468169594-4301-627b661e9736d
# 2  2022-05-16  1515915625471138230-4437-6282242f27843
# 3  2022-05-16  1515915625471138230-4437-6282242f27843
# 4  2022-05-16  1515915625471138230-4437-6282242f27843
# client_id         int64
# quantity          int64
# price           float64
# category_ids     object
# date             object
# message_id       object
# dtype: object
# ---------- end df_apparel_purchases ----------
#
# ---------- start df_apparel_target_binary ----------
#              client_id  target
# 0  1515915625468060902       0
# 1  1515915625468061003       1
# 2  1515915625468061099       0
# 3  1515915625468061100       0
# 4  1515915625468061170       0
# client_id    int64
# target       int64
# dtype: object
# ---------- end df_apparel_target_binary ----------

# %% [markdown]
# Предварительные выводы:
# - имена колонок корректные
# - поля event и channel являются категориями, изменим им тип на category
# - поля date и created_at дате (должны быть типа datetime), изменим им тип при загрузке полных данных

# %%
df_apparel_messages_original = load_csv(".private/apparel-messages.csv", dtype={"event": "category", "channel": "category"}, parse_dates=["date", "created_at"])
df_apparel_messages = df_apparel_messages_original.copy()
# Out:
# Dataset path: .private/apparel-messages.csv

# %%
df_apparel_purchases_original = load_csv(".private/apparel-purchases.csv", parse_dates=["date"])
df_apparel_purchases = df_apparel_purchases_original.copy()
# Out:
# Dataset path: .private/apparel-purchases.csv

# %%
df_apparel_target_binary_original = load_csv(".private/apparel-target_binary.csv")
df_apparel_target_binary = df_apparel_target_binary_original.copy()
# Out:
# Dataset path: .private/apparel-target_binary.csv

# %% [markdown]
# ### Промежуточные выводы

# %% [markdown]
# Данные загружены, выглядят корректно, типы признаков правильные

# %% [markdown]
# ## Предобработка данных

# %% [markdown]
# ### Первичный анализ данных

# %%
df_dict = {
    "df_apparel_messages": df_apparel_messages,
    "df_apparel_purchases": df_apparel_purchases,
    "df_apparel_target_binary": df_apparel_target_binary,
    # "df_full_campaign_daily_event": df_full_campaign_daily_event,
    # "df_full_campaign_daily_event_channel": df_full_campaign_daily_event_channel,
}

# %%
for df_name, df in df_dict.items():
    print(f"{'-' * 10} start: {df_name} {'-' * 10}\n")
    describe_dataset(df)
    print(f"\n{'-' * 10} end: {df_name} {'-' * 10}\n")
# Out:
# ---------- start: df_apparel_messages ----------
#
# *** Общая информация ***
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12739798 entries, 0 to 12739797
# Data columns (total 7 columns):
#  #   Column            Dtype
# ---  ------            -----
#  0   bulk_campaign_id  int64
#  1   client_id         int64
#  2   message_id        object
#  3   event             category
#  4   channel           category
#  5   date              datetime64[ns]
#  6   created_at        datetime64[ns]
# dtypes: category(2), datetime64[ns](2), int64(2), object(1)
# memory usage: 510.3+ MB
# None
#
#
# *** Статистика по количественным данным ***
#        bulk_campaign_id                    client_id  \
# count     12,739,798.00                12,739,798.00
# mean          11,604.59 1,515,915,625,574,831,616.00
# min              548.00 1,515,915,625,468,060,928.00
# 25%            8,746.00 1,515,915,625,489,149,440.00
# 50%           13,516.00 1,515,915,625,503,432,192.00
# 75%           14,158.00 1,515,915,625,591,286,272.00
# max           14,657.00 1,515,915,626,010,288,640.00
# std            3,259.21               326,551,798.16
#
#                                 date                     created_at
# count                       12739798                       12739798
# mean   2023-06-05 02:46:08.357990400  2023-06-05 13:58:11.168689408
# min              2022-05-19 00:00:00            2022-05-19 00:14:20
# 25%              2022-12-19 00:00:00            2022-12-19 12:46:30
# 50%              2023-07-20 00:00:00            2023-07-20 17:21:54
# 75%              2023-11-21 00:00:00            2023-11-21 18:13:05
# max              2024-02-15 00:00:00            2024-02-15 23:58:40
# std                              NaN                            NaN
# *** Статистика по категориальным данным ***
#                                     message_id     event      channel
# count                                 12739798  12739798     12739798
# unique                                 9061667        11            2
# top     1515915625489095763-6251-6311b13a4cf78      send  mobile_push
# freq                                      1454   9058196      7512156
#
#
# *** Информация по колонкам ***
#                             type  na_count  empty_count  unique_count
# bulk_campaign_id           int64         0            0          2709
# client_id                  int64         0            0         53329
# message_id                object         0            0       9061667
# event                   category         0            0            11
# channel                 category         0            0             2
# date              datetime64[ns]         0            0           638
# created_at        datetime64[ns]         0            0       4103539
# *** Количество дубликатов: 48610 ***
#
#
# *** Первые 5 строк датасета ***
#    bulk_campaign_id            client_id  \
# 0              4439  1515915625626736623
# 1              4439  1515915625490086521
# 2              4439  1515915625553578558
# 3              4439  1515915625553578558
# 4              4439  1515915625471518311
#
#                                message_id  event channel       date  \
# 0  1515915625626736623-4439-6283415ac07ea   open   email 2022-05-19
# 1  1515915625490086521-4439-62834150016dd   open   email 2022-05-19
# 2  1515915625553578558-4439-6283415b36b4f   open   email 2022-05-19
# 3  1515915625553578558-4439-6283415b36b4f  click   email 2022-05-19
# 4  1515915625471518311-4439-628341570c133   open   email 2022-05-19
#
#            created_at
# 0 2022-05-19 00:14:20
# 1 2022-05-19 00:39:34
# 2 2022-05-19 00:51:49
# 3 2022-05-19 00:52:20
# 4 2022-05-19 00:56:52
# ---------- end: df_apparel_messages ----------
#
# ---------- start: df_apparel_purchases ----------
#
# *** Общая информация ***
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 202208 entries, 0 to 202207
# Data columns (total 6 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   client_id     202208 non-null  int64
#  1   quantity      202208 non-null  int64
#  2   price         202208 non-null  float64
#  3   category_ids  202208 non-null  object
#  4   date          202208 non-null  datetime64[ns]
#  5   message_id    202208 non-null  object
# dtypes: datetime64[ns](1), float64(1), int64(2), object(2)
# memory usage: 9.3+ MB
# None
#
#
# *** Статистика по количественным данным ***
#                          client_id   quantity      price  \
# count                   202,208.00 202,208.00 202,208.00
# mean  1,515,915,625,596,210,944.00       1.01   1,193.30
# min   1,515,915,625,468,060,928.00       1.00       1.00
# 25%   1,515,915,625,490,081,280.00       1.00     352.00
# 50%   1,515,915,625,557,177,088.00       1.00     987.00
# 75%   1,515,915,625,624,391,936.00       1.00   1,699.00
# max   1,515,915,626,010,443,520.00      30.00  85,499.00
# std                 145,951,436.37       0.18   1,342.25
#
#                                 date
# count                         202208
# mean   2023-03-17 02:49:35.739832064
# min              2022-05-16 00:00:00
# 25%              2022-11-12 00:00:00
# 50%              2023-04-12 00:00:00
# 75%              2023-07-03 00:00:00
# max              2024-02-16 00:00:00
# std                              NaN
# *** Статистика по категориальным данным ***
#                     category_ids                              message_id
# count                     202208                                  202208
# unique                       933                                   50204
# top     ['4', '28', '57', '431']  1515915625489095763-6251-6311b13a4cf78
# freq                        8626                                     365
#
#
# *** Информация по колонкам ***
#                         type  na_count  empty_count  unique_count
# client_id              int64         0            0         49849
# quantity               int64         0            0            16
# price                float64         0            0          3642
# category_ids          object         0            0           933
# date          datetime64[ns]         0            0           642
# message_id            object         0            0         50204
# *** Количество дубликатов: 73020 ***
#
#
# *** Первые 5 строк датасета ***
#              client_id  quantity    price               category_ids  \
# 0  1515915625468169594         1 1,999.00   ['4', '28', '57', '431']
# 1  1515915625468169594         1 2,499.00   ['4', '28', '57', '431']
# 2  1515915625471138230         1 6,499.00   ['4', '28', '57', '431']
# 3  1515915625471138230         1 4,999.00  ['4', '28', '244', '432']
# 4  1515915625471138230         1 4,999.00   ['4', '28', '49', '413']
#
#         date                              message_id
# 0 2022-05-16  1515915625468169594-4301-627b661e9736d
# 1 2022-05-16  1515915625468169594-4301-627b661e9736d
# 2 2022-05-16  1515915625471138230-4437-6282242f27843
# 3 2022-05-16  1515915625471138230-4437-6282242f27843
# 4 2022-05-16  1515915625471138230-4437-6282242f27843
# ---------- end: df_apparel_purchases ----------
#
# ---------- start: df_apparel_target_binary ----------
#
# *** Общая информация ***
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 49849 entries, 0 to 49848
# Data columns (total 2 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   client_id  49849 non-null  int64
#  1   target     49849 non-null  int64
# dtypes: int64(2)
# memory usage: 779.0 KB
# None
#
#
# *** Статистика по количественным данным ***
#                          client_id    target
# count                    49,849.00 49,849.00
# mean  1,515,915,625,598,796,032.00      0.02
# std                 148,794,665.09      0.14
# min   1,515,915,625,468,060,928.00      0.00
# 25%   1,515,915,625,489,972,736.00      0.00
# 50%   1,515,915,625,556,614,912.00      0.00
# 75%   1,515,915,625,633,408,768.00      0.00
# max   1,515,915,626,010,443,520.00      1.00
# *** Статистика по категориальным данным ***
# Нет категориальных признаков для анализа.
#
#
# *** Информация по колонкам ***
#             type  na_count  empty_count  unique_count
# client_id  int64         0            0         49849
# target     int64         0            0             2
# *** Количество дубликатов: 0 ***
#
#
# *** Первые 5 строк датасета ***
#              client_id  target
# 0  1515915625468060902       0
# 1  1515915625468061003       1
# 2  1515915625468061099       0
# 3  1515915625468061100       0
# 4  1515915625468061170       0
# ---------- end: df_apparel_target_binary ----------

# %% [markdown]
# Найдем все значения категориальных признаков

# %%
print("event:\n", df_apparel_messages["event"].unique().tolist())
print("channel:\n", df_apparel_messages["channel"].unique().tolist())
# Out:
# event:
#  ['open', 'click', 'purchase', 'send', 'unsubscribe', 'hbq_spam', 'hard_bounce', 'subscribe', 'soft_bounce', 'complain', 'close']
# channel:
#  ['email', 'mobile_push']

# %% [markdown]
# Предварительные выводы:
# - данные не содержат пропусков, но содержат дубликаты
# - данные за период Май 2022 - Ферваль 2024
# - в датасете df_apparel_purchases меньше уникальных client_id, чем в df_apparel_messages. Вероятно, разница из-за "мертвых" клиентов, которые не совершали покупок в указанный период
# - поле message_id состоит из объединения нескольких признаков: client_id, bulk_campaign_id, specific_message_id

# %% [markdown]
# ### Выделение message_id

# %%
# Проверочное условие
expected_pattern = df_apparel_messages['client_id'].astype(str) + '-' + df_apparel_messages['bulk_campaign_id'].astype(str) + '-' + df_apparel_messages['message_id'].str.split('-').str[-1]
matches = expected_pattern == df_apparel_messages['message_id']

print(f"Количество записей, не соответствующих шаблону: {df_apparel_messages[~matches].shape[0]}")
# Out:
# Количество записей, не соответствующих шаблону: 0

# %%
df_apparel_messages["message_id"] = df_apparel_messages["message_id"].apply(lambda x: x.split("-")[-1])
df_apparel_messages.head()
# Out:
#    bulk_campaign_id            client_id     message_id  event channel  \
# 0              4439  1515915625626736623  6283415ac07ea   open   email
# 1              4439  1515915625490086521  62834150016dd   open   email
# 2              4439  1515915625553578558  6283415b36b4f   open   email
# 3              4439  1515915625553578558  6283415b36b4f  click   email
# 4              4439  1515915625471518311  628341570c133   open   email
#
#         date          created_at
# 0 2022-05-19 2022-05-19 00:14:20
# 1 2022-05-19 2022-05-19 00:39:34
# 2 2022-05-19 2022-05-19 00:51:49
# 3 2022-05-19 2022-05-19 00:52:20
# 4 2022-05-19 2022-05-19 00:56:52

# %%
df_apparel_purchases["message_id"] = df_apparel_purchases["message_id"].apply(lambda x: x.split("-")[-1])
df_apparel_purchases.head()
# Out:
#              client_id  quantity    price               category_ids  \
# 0  1515915625468169594         1 1,999.00   ['4', '28', '57', '431']
# 1  1515915625468169594         1 2,499.00   ['4', '28', '57', '431']
# 2  1515915625471138230         1 6,499.00   ['4', '28', '57', '431']
# 3  1515915625471138230         1 4,999.00  ['4', '28', '244', '432']
# 4  1515915625471138230         1 4,999.00   ['4', '28', '49', '413']
#
#         date     message_id
# 0 2022-05-16  627b661e9736d
# 1 2022-05-16  627b661e9736d
# 2 2022-05-16  6282242f27843
# 3 2022-05-16  6282242f27843
# 4 2022-05-16  6282242f27843

# %% [markdown]
# ### Наличие явных дубликатов

# %% [markdown]
# Проверим наличие явных дубликатов

# %%
def detect_duplicates(df):
    """
    Выводит общее количество дубликатов, первые 5 строк с дубликатами или сообщение "Явных дубликатов не обнаружено".
    
    Параметры:
    - df (pandas.DataFrame): Исходный датасет.
    """
    # Поиск дубликатов
    duplicated_rows = df[df.duplicated()]

    # Вывод результата
    if len(duplicated_rows) > 0:
        print(f"Общее количество дубликатов: {len(duplicated_rows)}")
        display(duplicated_rows.head())
    else:
        print("Явных дубликатов не обнаружено.")

# %%
df_dict = {
    "df_apparel_messages": df_apparel_messages,
    "df_apparel_purchases": df_apparel_purchases,
}

for df_name, df in df_dict.items():
    print(f"{'-' * 10} start: {df_name} {'-' * 10}\n")
    detect_duplicates(df)
    print(f"\n{'-' * 10} end: {df_name} {'-' * 10}\n")
# Out:
# ---------- start: df_apparel_messages ----------
#
# Общее количество дубликатов: 48610
#         bulk_campaign_id            client_id     message_id  event  \
# 964232              5723  1515915625554535987  62e2af08e00da  click
# 966466              5723  1515915625483569932  62e2af0790ad5  click
# 967282              5723  1515915625736038297  62e2af0a17cba  click
# 967567              5723  1515915625753898206  62e2af0a21ecd  click
# 967904              5723  1515915625626349443  62e2af09c0fd3  click
#
#             channel       date          created_at
# 964232  mobile_push 2022-07-28 2022-07-28 15:58:56
# 966466  mobile_push 2022-07-28 2022-07-28 16:07:12
# 967282  mobile_push 2022-07-28 2022-07-28 16:09:56
# 967567  mobile_push 2022-07-28 2022-07-28 16:12:24
# 967904  mobile_push 2022-07-28 2022-07-28 16:15:02
# ---------- end: df_apparel_messages ----------
#
# ---------- start: df_apparel_purchases ----------
#
# Общее количество дубликатов: 73020
#               client_id  quantity    price                     category_ids  \
# 12  1515915625491869271         2   599.00       ['4', '27', '350', '1392']
# 22  1515915625566606509         1   299.00  ['5562', '5634', '5579', '710']
# 42  1515915625468070175         1 2,199.00        ['4', '27', '142', '496']
# 59  1515915625468126078         1 1,499.00        ['4', '28', '275', '421']
# 62  1515915625468141317         1    49.00         ['4', '27', '38', '481']
#
#          date     message_id
# 12 2022-05-16  61a72488d6a0f
# 22 2022-05-16  627b66245401d
# 42 2022-05-17  6283414668daa
# 59 2022-05-17  6283411f7c0cc
# 62 2022-05-17  6283412e01078
# ---------- end: df_apparel_purchases ----------

# %% [markdown]
# ### Выборочная проверка явных дубликатов

# %%
df_apparel_messages.query("client_id == 1515915625554535987 and message_id == '62e2af08e00da'").head()
# Out:
#         bulk_campaign_id            client_id     message_id     event  \
# 964169              5723  1515915625554535987  62e2af08e00da      send
# 964231              5723  1515915625554535987  62e2af08e00da     click
# 964232              5723  1515915625554535987  62e2af08e00da     click
# 968252              5723  1515915625554535987  62e2af08e00da  purchase
# 968266              5723  1515915625554535987  62e2af08e00da  purchase
#
#             channel       date          created_at
# 964169  mobile_push 2022-07-28 2022-07-28 15:58:49
# 964231  mobile_push 2022-07-28 2022-07-28 15:58:56
# 964232  mobile_push 2022-07-28 2022-07-28 15:58:56
# 968252  mobile_push 2022-07-28 2022-07-28 17:29:17
# 968266  mobile_push 2022-07-28 2022-07-28 17:38:31

# %%
df_apparel_purchases.query("client_id == 1515915625554535987 and message_id == '62e2af08e00da'").head()
# Out:
#                  client_id  quantity  price               category_ids  \
# 26803  1515915625554535987         1 199.00  ['4', '28', '213', '417']
# 26804  1515915625554535987         1 399.00  ['4', '28', '239', '418']
# 26805  1515915625554535987         1 399.00  ['4', '28', '239', '418']
# 26806  1515915625554535987         1 199.00  ['4', '28', '275', '673']
# 26807  1515915625554535987         1 999.00   ['4', '28', '57', '431']
#
#             date     message_id
# 26803 2022-07-28  62e2af08e00da
# 26804 2022-07-28  62e2af08e00da
# 26805 2022-07-28  62e2af08e00da
# 26806 2022-07-28  62e2af08e00da
# 26807 2022-07-28  62e2af08e00da

# %% [markdown]
# Вряд ли возможно по пуш уведомлению кликнуть дважды и в одно время с точностью до секунды. Пуш ведет либо на сайт, либо в мобильное приложение. Кажется, можно сделать несколько одинаковых заказов в один день в приложении или на сайте, если их не закрывать после перехода. Другое дело, что с точки зрения логики поведения это выглядит очень нелогично.
#
# Посмотрим дубликаты для email рассылок.

# %%
mask = df_apparel_messages.duplicated()
df_apparel_messages[mask].query("channel == 'email'").head()
# Out:
#          bulk_campaign_id            client_id     message_id  event channel  \
# 1404039              6251  1515915625489095763  6311b13a4cf78  click   email
# 1855332              6963  1515915625491167405  633fcb4b0f3aa   send   email
# 2206285              7475  1515915625489705746  635f80baf2917  click   email
# 2207643              7475  1515915625474233185  635f80ad6e24a  click   email
# 2222046              7475  1515915625470759244  635f80b16e23a  click   email
#
#               date          created_at
# 1404039 2022-09-03 2022-09-03 12:58:02
# 1855332 2022-10-07 2022-10-07 08:43:51
# 2206285 2022-10-31 2022-10-31 11:11:49
# 2207643 2022-10-31 2022-10-31 14:29:00
# 2222046 2022-11-01 2022-11-01 02:38:13

# %%
df_apparel_messages.query("client_id == 1515915625489705746 and message_id == '635f80baf2917'").head()
# Out:
#          bulk_campaign_id            client_id     message_id     event  \
# 2200737              7475  1515915625489705746  635f80baf2917      send
# 2206281              7475  1515915625489705746  635f80baf2917      open
# 2206284              7475  1515915625489705746  635f80baf2917     click
# 2206285              7475  1515915625489705746  635f80baf2917     click
# 2231774              7475  1515915625489705746  635f80baf2917  purchase
#
#         channel       date          created_at
# 2200737   email 2022-10-31 2022-10-31 09:34:31
# 2206281   email 2022-10-31 2022-10-31 11:11:29
# 2206284   email 2022-10-31 2022-10-31 11:11:49
# 2206285   email 2022-10-31 2022-10-31 11:11:49
# 2231774   email 2022-11-01 2022-11-01 15:00:50

# %%
df_apparel_purchases.query("client_id == 1515915625489705746 and message_id == '635f80baf2917'").head()
# Out:
#                  client_id  quantity    price               category_ids  \
# 41514  1515915625489705746         1 2,450.00  ['4', '28', '104', '429']
#
#             date     message_id
# 41514 2022-11-01  635f80baf2917

# %% [markdown]
# А вот кликнуть дважды по кнопке в email в одну секунду выглядит вполне возможным.
#
# Тем не менее, дублирование негативно сказывается на результатах обучения и предсказательных характеристиках моделей машинного обучения. Устранение дубликатов способствует повышению надёжности и стабильности моделей.

# %%
df_apparel_messages = df_apparel_messages.drop_duplicates()
check_size(df_apparel_messages, df_apparel_messages_original)
# Out:
# Количество записей в текущем датасете: 12691188
# Количество записей в оригинальном датасете: 12739798
# Процент от начального объема данных: 99.62%

# %%
df_apparel_purchases = df_apparel_purchases.drop_duplicates()
check_size(df_apparel_purchases, df_apparel_purchases_original)
# Out:
# Количество записей в текущем датасете: 129188
# Количество записей в оригинальном датасете: 202208
# Процент от начального объема данных: 63.89%

# %% [markdown]
# ### Неявные дубликаты

# %%
import pandas as pd
from Levenshtein import distance
from collections import defaultdict, Counter


def normalize_string(s):
    # Удаляем лишнюю пунктуацию и пробелы, приводим к нижнему регистру
    s = ''.join(c for c in s if c.isalnum() or c.isspace()).strip().lower()
    return s


def find_implicit_duplicates(dataframe):
    results = []

    category_cols = dataframe.select_dtypes(include=['category']).columns
    
    for column_name in category_cols:
        values = dataframe[column_name].values.tolist()
        
        # Создаем словарь соответствия оригинальных значений и их нормализованных версий
        normalized_values = {v: normalize_string(v) for v in values}
        
        # Сохраняем оригинальные значения, соответствующие каждой нормализованной форме
        inverse_mapping = defaultdict(list)
        for orig_val, norm_val in normalized_values.items():
            inverse_mapping[norm_val].append(orig_val)
        
        # Уникальные нормализованные значения
        unique_normalized_values = list(inverse_mapping.keys())
        
        # Создание групп похожих значений
        similar_groups = defaultdict(list)
        
        # Объединяем похожие нормализованные значения в одну группу
        for norm_val in unique_normalized_values:
            found_group = False
            for existing_group in similar_groups:
                dist = distance(norm_val, existing_group)
                if dist <= len(existing_group) * 0.2:  # Расстояние <= 20%
                    similar_groups[existing_group].extend(inverse_mapping[norm_val])
                    found_group = True
                    break
            if not found_group:
                similar_groups[norm_val] = inverse_mapping[norm_val]
        
        # Формируем итоговый отчет
        result_column = f'Столбец: {column_name}\n'
        has_duplicates = False
        for group_key, group_members in sorted(similar_groups.items(), key=lambda x: len(x[1]), reverse=True):
            # Выбор самого популярного оригинального значения
            most_common_value = Counter(group_members).most_common(1)[0][0]
            similar_values = [v for v in group_members if v != most_common_value]
            
            if similar_values:
                has_duplicates = True
                result_column += f'- Наиболее частое значение: {most_common_value}\nПодобные значения: {similar_values}\n\n'
        
        if not has_duplicates:
            result_column += '- Неявных дубликатов не обнаружено.\n'
        
        results.append(result_column)
    
    return '\n'.join(results)

print(find_implicit_duplicates(df_apparel_messages))
# Out:
# Столбец: event
# - Наиболее частое значение: unsubscribe
# Подобные значения: ['subscribe']
#
#
# Столбец: channel
# - Неявных дубликатов не обнаружено.

# %% [markdown]
# События unsubscribe и subscribe не являются неявными дубликатами. Это разные события.

# %% [markdown]
# ### Промежуточные выводы

# %% [markdown]
# В ходе предварительной обработки данных было сделано следующее:
# - проведена проверка на наличие пропусков в данных. Пропусков не обнаружено
# - проведена проверка на наличие дубликатов, явные дубликаты удалены
# - проведена проверка на полноту данных после проведения предобработки
# - неявных дубликатов не обнаружено

# %% [markdown]
# ## Исследовательский анализ данных

# %% [markdown]
# ### Количественные признаки

# %%
def visualize_numerical_distribution_and_range(df, bins_rule="sturges", numeric_cols=None):
    """
    Рисует графики распределения (гистограмма) и размаха (коробчатая диаграмма) для всех числовых признаков.

    Параметры:
    - df (pandas.DataFrame): Исходный датасет.
    - bins_rule (str): Правило для автоматического подбора количества корзин. Возможные значения:
                     'sturges' (правило Стерджеса) или 'sqrt' (корень квадратный).
    """
    # Отбираем только числовые столбцы
    if numeric_cols is None or not list(numeric_cols):
        numeric_cols = df.select_dtypes(include=["number"]).columns

    # Функция для автоматического подбора количества корзин
    def auto_binning(data_length, rule=bins_rule):
        if rule == "sturges":
            return int(math.ceil(math.log2(data_length))) + 1
        elif rule == "sqrt":
            return int(math.sqrt(data_length))
        else:
            raise ValueError("Invalid binning rule provided.")

    # Проходим по каждому числовому столбцу и строим графики
    for col in numeric_cols:
        # Подбор оптимального количества корзин
        optimal_bins = auto_binning(len(df))

        # Гистограмма с боксплотом (график распределения и размаха)
        fig = px.histogram(
            df,
            x=col,
            marginal="box",
            barmode="group",
            nbins=optimal_bins,
            title=f'Распределение и размах для признака "{col}"',
        )

        # Визуализация графика
        fig.show()

# %%
numeric_columns = df_apparel_messages.select_dtypes(include=['number']).columns.drop(['client_id'])
numeric_columns
# Out:
# Index(['bulk_campaign_id'], dtype='object')

# %%
# visualize_numerical_distribution_and_range(df_apparel_messages, "sqrt", numeric_columns)

# Провести анализ количественных признаков для датасета df_apparel_messages не получилось, 
# т.к. падает ядро и docker container с jupyter server уходит в reboot.
# Такое поведение, вероятно, связано с большим объемом данных в датасете

# %%
numeric_columns = df_apparel_purchases.select_dtypes(include=['number']).columns.drop(['client_id'])
numeric_columns
# Out:
# Index(['quantity', 'price'], dtype='object')

# %%
visualize_numerical_distribution_and_range(df_apparel_purchases, "sqrt", numeric_columns)

# %% [markdown]
# Подавляющее большинство покупок было совершено на сумму в пределах 3777 и в количестве 1 шт

# %% [markdown]
# ### Категориальные признаки

# %%
def visualize_categorical_columns(df, category_cols=None):
    """
    Строит столбчатые и круговые диаграммы для категориальных признаков датасета.
    
    Параметры:
    - df (pandas.DataFrame): Исходный датасет.
    """
    # Получаем список категориальных столбцов
    if category_cols is None or not list(category_cols):
        category_cols = df.select_dtypes(exclude=['number']).columns
    
    # Для каждого категориального столбца строим диаграммы
    for col in category_cols:
        # Частотная таблица для столбца
        freq_table = df[col].value_counts()
        
        # Бар-чарт (столбчатая диаграмма)
        fig_bar = px.bar(freq_table, x=freq_table.index, y=freq_table.values, 
                         labels={"x": f"{col}", "y": "Частота"},
                         title=f"Бар-диаграмма для {col}")
        fig_bar.show()
        
        # Круговая диаграмма (pie chart)
        fig_pie = px.pie(names=freq_table.index, values=freq_table.values, 
                         title=f"Круговая диаграмма для {col}")
        fig_pie.show()

# %%
category_columns = df_apparel_messages.select_dtypes(include=['category']).columns
category_columns
# Out:
# Index(['event', 'channel'], dtype='object')

# %%
visualize_categorical_columns(df_apparel_messages, category_columns)

# %% [markdown]
# Визуализируем конверсию событий ['send','open', 'click', 'purchase']

# %%
events = ['send','open', 'click', 'purchase']

df_apparel_messages_events_grouped = df_apparel_messages.groupby('event', as_index=False).size().sort_values(by='size', ascending=False).rename(columns={'size': 'count'})
df_apparel_messages_events_filtered = df_apparel_messages_events_grouped[df_apparel_messages_events_grouped['event'].isin(events)]
df_apparel_messages_events_filtered
# Out:
#       event    count
# 5      send  9058174
# 3      open  3052481
# 0     click   483326
# 4  purchase    62593

# %%
def visualize_conversion(df):
    max_count = df['count'].max()  # Получаем максимальное количество событий
    
    # Добавляем столбец с процентами от максимального значения
    df['percent'] = round((df['count'] / max_count * 100), 2).astype(str) + '%'
    
    # Создаем график типа funnel
    fig = px.funnel(df, x='count', y='event',
                    title="Конверсия событий",
                    labels={'count': 'Количество событий'},
                    color_discrete_sequence=px.colors.sequential.Rainbow,
                    template='simple_white')
    
    # Обновляем подписи на графике, добавив проценты
    fig.update_traces(texttemplate='%{label}<br>%{value:.0f}<br>(%{customdata})', customdata=df['percent'])
    
    # Отображаем графически
    fig.show()

# Применяем функцию к вашему датасету
visualize_conversion(df_apparel_messages_events_filtered)

# %% [markdown]
# Было разослано более 9М сообщений, из которых открыто ~3М, а покупку совершили всего в 62.5К случаев (0.69% событий от всех разосланных сообщений)
#
# Большинство уведомлений было push уведомлениями.

# %% [markdown]
# ### Промежуточные выводы

# %% [markdown]
# Был проведен исследовательский анализ количественных и категориальных признаков из датасетов.
# - Подавляющее большинство покупок было совершено на сумму в пределах 3777 и в количестве 1 шт
# - Разослано более 9М сообщений, из которых открыто примерно 3М, а покупку совершили всего в 62.5К случаев
# - Большинство уведомлений было push уведомлениями

# %% [markdown]
# ## Создание новых признаков

# %% [markdown]
# Найдем количество всех event для каждого клиента

# %%
df_apparel_messages_pivot = df_apparel_messages.pivot_table(
    values="message_id",
    index="client_id", 
    columns="event", 
    aggfunc="count"
)
df_apparel_messages_pivot.head()
# Out:
# event                click  hard_bounce  hbq_spam  open  purchase  send  \
# client_id
# 1515915625468060902     10            0         0    35         5   126
# 1515915625468061003      5            0         0     5         1   154
# 1515915625468061099      8            2         0    51         0   215
# 1515915625468061100      1            1         0   157         1   267
# 1515915625468061170     16            0         0    31         3   243
#
# event                soft_bounce  subscribe  unsubscribe  complain  close
# client_id
# 1515915625468060902            0          0            1         0      0
# 1515915625468061003            0          0            0         0      0
# 1515915625468061099            0          0            0         0      0
# 1515915625468061100            1          0            0         0      0
# 1515915625468061170            0          0            0         0      0

# %% [markdown]
# Получили общую статистику по реакциям пользователя на рассылки

# %% [markdown]
# Найдем максимальную дату покупки из датасета

# %%
last_date = df_apparel_purchases['date'].max()
last_date
# Out:
# Timestamp('2024-02-16 00:00:00')

# %% [markdown]
# Предоставленые данные до середины февраля 2024, а цель -- предсказать вероятность покупки в ближайшие 90 дней (3 месяца).

# %% [markdown]
# Получим статистику по покупкам пользователей

# %%
df_apparel_purchases_pivot = df_apparel_purchases.pivot_table(
    values=["price", "quantity"],
    index="client_id", 
    aggfunc="sum",
    fill_value=0
)
df_apparel_purchases_pivot.head()
# Out:
#                         price  quantity
# client_id
# 1515915625468060902  4,795.00         5
# 1515915625468061003 14,135.00         6
# 1515915625468061099    299.00         1
# 1515915625468061100  1,049.00         1
# 1515915625468061170 14,102.00         8

# %% [markdown]
# Найдем даты первой и последней покупки

# %%
df_apparel_purchases_dates = df_apparel_purchases.groupby("client_id").agg(
    first_buy_date=("date", "min"),
    last_buy_date=("date", "max"),
)
df_apparel_purchases_dates.head()
# Out:
#                     first_buy_date last_buy_date
# client_id
# 1515915625468060902     2022-05-27    2022-05-27
# 1515915625468061003     2023-01-04    2023-01-04
# 1515915625468061099     2022-05-17    2022-05-17
# 1515915625468061100     2024-02-10    2024-02-10
# 1515915625468061170     2023-03-26    2023-06-17

# %% [markdown]
# Объединим полученные датасеты

# %%
df_clients = df_apparel_messages_pivot.join(df_apparel_purchases_pivot).join(df_apparel_purchases_dates)

df_clients = df_clients.fillna(0)
df_clients['first_buy_date'] = pd.to_datetime(df_clients['first_buy_date'])
df_clients['last_buy_date'] = pd.to_datetime(df_clients['last_buy_date'])

df_clients.head()
# Out:
#                      click  hard_bounce  hbq_spam  open  purchase  send  \
# client_id
# 1515915625468060902     10            0         0    35         5   126
# 1515915625468061003      5            0         0     5         1   154
# 1515915625468061099      8            2         0    51         0   215
# 1515915625468061100      1            1         0   157         1   267
# 1515915625468061170     16            0         0    31         3   243
#
#                      soft_bounce  subscribe  unsubscribe  complain  close  \
# client_id
# 1515915625468060902            0          0            1         0      0
# 1515915625468061003            0          0            0         0      0
# 1515915625468061099            0          0            0         0      0
# 1515915625468061100            1          0            0         0      0
# 1515915625468061170            0          0            0         0      0
#
#                         price  quantity first_buy_date last_buy_date
# client_id
# 1515915625468060902  4,795.00      5.00     2022-05-27    2022-05-27
# 1515915625468061003 14,135.00      6.00     2023-01-04    2023-01-04
# 1515915625468061099    299.00      1.00     2022-05-17    2022-05-17
# 1515915625468061100  1,049.00      1.00     2024-02-10    2024-02-10
# 1515915625468061170 14,102.00      8.00     2023-03-26    2023-06-17

# %% [markdown]
# Найдем общее количество дней на маркетплейсе и количество дней с последней покупки

# %%
df_clients['recent_activity_days'] = (last_date - df_clients['last_buy_date']).dt.days

# когда даты первой и последней покупки совпадают следует добавить 1, иначе будет 0
df_clients['total_days'] = (df_clients['last_buy_date'] - df_clients['first_buy_date']).dt.days + 1 
df_clients.head()
# Out:
#                      click  hard_bounce  hbq_spam  open  purchase  send  \
# client_id
# 1515915625468060902     10            0         0    35         5   126
# 1515915625468061003      5            0         0     5         1   154
# 1515915625468061099      8            2         0    51         0   215
# 1515915625468061100      1            1         0   157         1   267
# 1515915625468061170     16            0         0    31         3   243
#
#                      soft_bounce  subscribe  unsubscribe  complain  close  \
# client_id
# 1515915625468060902            0          0            1         0      0
# 1515915625468061003            0          0            0         0      0
# 1515915625468061099            0          0            0         0      0
# 1515915625468061100            1          0            0         0      0
# 1515915625468061170            0          0            0         0      0
#
#                         price  quantity first_buy_date last_buy_date  \
# client_id
# 1515915625468060902  4,795.00      5.00     2022-05-27    2022-05-27
# 1515915625468061003 14,135.00      6.00     2023-01-04    2023-01-04
# 1515915625468061099    299.00      1.00     2022-05-17    2022-05-17
# 1515915625468061100  1,049.00      1.00     2024-02-10    2024-02-10
# 1515915625468061170 14,102.00      8.00     2023-03-26    2023-06-17
#
#                      recent_activity_days  total_days
# client_id
# 1515915625468060902                   630           1
# 1515915625468061003                   408           1
# 1515915625468061099                   640           1
# 1515915625468061100                     6           1
# 1515915625468061170                   244          84

# %%
df_clients.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 53329 entries, 1515915625468060902 to 1515915626010288690
# Data columns (total 17 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   click                 53329 non-null  int64
#  1   hard_bounce           53329 non-null  int64
#  2   hbq_spam              53329 non-null  int64
#  3   open                  53329 non-null  int64
#  4   purchase              53329 non-null  int64
#  5   send                  53329 non-null  int64
#  6   soft_bounce           53329 non-null  int64
#  7   subscribe             53329 non-null  int64
#  8   unsubscribe           53329 non-null  int64
#  9   complain              53329 non-null  int64
#  10  close                 53329 non-null  int64
#  11  price                 53329 non-null  float64
#  12  quantity              53329 non-null  float64
#  13  first_buy_date        53329 non-null  datetime64[ns]
#  14  last_buy_date         53329 non-null  datetime64[ns]
#  15  recent_activity_days  53329 non-null  int64
#  16  total_days            53329 non-null  int64
# dtypes: datetime64[ns](2), float64(2), int64(13)
# memory usage: 7.3 MB

# %% [markdown]
# Добавим к полученному датасету целевой признак

# %%
df_apparel_target_binary = df_apparel_target_binary.set_index('client_id')
df_apparel_target_binary.head()
# Out:
#                      target
# client_id
# 1515915625468060902       0
# 1515915625468061003       1
# 1515915625468061099       0
# 1515915625468061100       0
# 1515915625468061170       0

# %%
df_apparel_target_binary.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 49849 entries, 1515915625468060902 to 1515915626010443624
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   target  49849 non-null  int64
# dtypes: int64(1)
# memory usage: 778.9 KB

# %% [markdown]
# Выберем тип соединения inner, т.к. в противном случае у нас либо не будет статистики, либо целевого признака. Такие данные невозможно использовать для обучения моделей.

# %%
df_clients_full = df_clients.join(df_apparel_target_binary, how="inner")
df_clients_full.head()
# Out:
#                      click  hard_bounce  hbq_spam  open  purchase  send  \
# client_id
# 1515915625468060902     10            0         0    35         5   126
# 1515915625468061003      5            0         0     5         1   154
# 1515915625468061099      8            2         0    51         0   215
# 1515915625468061100      1            1         0   157         1   267
# 1515915625468061170     16            0         0    31         3   243
#
#                      soft_bounce  subscribe  unsubscribe  complain  close  \
# client_id
# 1515915625468060902            0          0            1         0      0
# 1515915625468061003            0          0            0         0      0
# 1515915625468061099            0          0            0         0      0
# 1515915625468061100            1          0            0         0      0
# 1515915625468061170            0          0            0         0      0
#
#                         price  quantity first_buy_date last_buy_date  \
# client_id
# 1515915625468060902  4,795.00      5.00     2022-05-27    2022-05-27
# 1515915625468061003 14,135.00      6.00     2023-01-04    2023-01-04
# 1515915625468061099    299.00      1.00     2022-05-17    2022-05-17
# 1515915625468061100  1,049.00      1.00     2024-02-10    2024-02-10
# 1515915625468061170 14,102.00      8.00     2023-03-26    2023-06-17
#
#                      recent_activity_days  total_days  target
# client_id
# 1515915625468060902                   630           1       0
# 1515915625468061003                   408           1       1
# 1515915625468061099                   640           1       0
# 1515915625468061100                     6           1       0
# 1515915625468061170                   244          84       0

# %%
df_clients_full.shape
# Out:
# (41982, 18)

# %% [markdown]
# В финальном датасете с новыми признаками осталось почти 42К записей

# %% [markdown]
# ### Промежуточные выводы

# %% [markdown]
# В данном разделе были созданы и добавлены новые признаки. Также проведено объединение всех признаков в один датасет и к нему добавлен целевой признак.

# %% [markdown]
# ## Корреляционный анализ

# %%
def correlation_heatmap(df, interval_cols=None):
    """
    Строит матрицу корреляции с использованием phik_matrix и выводит тепловую карту с аннотациями.
    
    Параметры:
    - df (pandas.DataFrame): Исходный датасет.
    """
    # Отбираем только числовые столбцы
    if interval_cols is None or not list(interval_cols):
        interval_cols = df.select_dtypes(include=["number"]).columns

    # Вычисляем матрицу корреляции Phik
    corr_matrix = phik_matrix(df, interval_cols=interval_cols, verbose=False)

    # Определяем оптимальный размер фигуры
    num_cols = len(corr_matrix.columns)
    size_per_col = 0.7  # размер графика на колонку
    figure_width = num_cols * size_per_col
    figure_height = num_cols * size_per_col

    # Вывод тепловой карты
    plt.figure(figsize=(figure_width, figure_height))
    sns.heatmap(corr_matrix, annot=True, fmt='.2f', cmap='coolwarm')
    plt.title("Матрица корреляции Phik")
    plt.show()

# %%
numeric_columns = df_clients_full.select_dtypes(include=["number"]).columns.drop(["target"])

correlation_heatmap(df_clients_full[numeric_columns])

# %% [markdown]
# Определим степень зависимости признака покупки от остальных признаков

# %%
def correlation_analysis(corr_matrix, target_column):
    """
    Анализирует матрицу корреляции и выводит степень зависимости целевого признака от остальных признаков.
    
    Параметры:
    - corr_matrix (pandas.DataFrame): Матрица корреляции.
    - target_column (str): Название целевого признака.
    """
    # Получаем строку с корреляциями целевого признака
    correlations = round(corr_matrix[target_column].abs(), 2)
    
    # Исключаем сам целевой признак
    correlations = correlations.drop(target_column)
    
    # Классифицируем зависимости согласно таблице
    very_low_dependency = correlations[(correlations >= 0) & (correlations < 0.2)].index.tolist()
    low_dependency = correlations[(correlations >= 0.2) & (correlations < 0.5)].index.tolist()
    medium_dependency = correlations[(correlations >= 0.5) & (correlations < 0.7)].index.tolist()
    high_dependency = correlations[(correlations >= 0.7) & (correlations < 0.9)].index.tolist()
    very_high_dependency = correlations[(correlations >= 0.9) & (correlations <= 1)].index.tolist()
    
    # Вывод результатов
    print(f"Признак {target_column} имеет:")
    if very_high_dependency:
        print(f"- очень высокую зависимость (> 0.9) от признаков {very_high_dependency}")
    if high_dependency:
        print(f"- высокую зависимость (0.7-0.9) от признаков {high_dependency}")
    if medium_dependency:
        print(f"- среднюю зависимость (0.5-0.7) от признаков {medium_dependency}")
    if low_dependency:
        print(f"- слабую зависимость (0.2-0.5) от признаков {low_dependency}")
    if very_low_dependency:
        print(f"- очень слабую зависимость (0-0.2) от признаков {very_low_dependency}")
    if not (very_high_dependency or high_dependency or medium_dependency or low_dependency or very_low_dependency):
        print("- признаков с достаточной степенью зависимости не найдено.")

# %%
corr_matrix = phik_matrix(df_clients_full[numeric_columns], verbose=False)

correlation_analysis(corr_matrix, "purchase")
# Out:
# Признак purchase имеет:
# - среднюю зависимость (0.5-0.7) от признаков ['click']
# - слабую зависимость (0.2-0.5) от признаков ['hard_bounce', 'price', 'quantity', 'total_days']
# - очень слабую зависимость (0-0.2) от признаков ['hbq_spam', 'open', 'send', 'soft_bounce', 'subscribe', 'unsubscribe', 'complain', 'close', 'recent_activity_days']

# %% [markdown]
# Удалим признаки с очень слабой корреляцией

# %%
cols_to_drop = ['hbq_spam', 'open', 'send', 'soft_bounce', 'subscribe', 'unsubscribe', 'complain', 'close', 'recent_activity_days']

df_clients_corr_features = df_clients_full.drop(columns=cols_to_drop)
df_clients_corr_features.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 41982 entries, 1515915625468060902 to 1515915626010261344
# Data columns (total 9 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   click           41982 non-null  int64
#  1   hard_bounce     41982 non-null  int64
#  2   purchase        41982 non-null  int64
#  3   price           41982 non-null  float64
#  4   quantity        41982 non-null  float64
#  5   first_buy_date  41982 non-null  datetime64[ns]
#  6   last_buy_date   41982 non-null  datetime64[ns]
#  7   total_days      41982 non-null  int64
#  8   target          41982 non-null  int64
# dtypes: datetime64[ns](2), float64(2), int64(5)
# memory usage: 3.2 MB

# %% [markdown]
# ### Промежуточные выводы

# %% [markdown]
# Матрица корреляции показала следующие зависимости признака purchase (факт совершения покупки в прошлом):
# - среднюю зависимость (0.5-0.7) от признаков ['click']
# - слабую зависимость (0.2-0.5) от признаков ['hard_bounce', 'price', 'quantity', 'total_days']
# - очень слабую зависимость (0-0.2) от признаков ['hbq_spam', 'open', 'send', 'soft_bounce', 'subscribe', 'unsubscribe', 'complain', 'close', 'recent_activity_days']
#
# Признаки с очень слабой корреляцией были удалены из датасета

# %% [markdown]
# ## Подготовка данных

# %%
RANDON_STATE = 1
TEST_SIZE = 0.25

# Отделяем признаки и цель
X = df_clients_corr_features.drop("target", axis=1)
y = df_clients_corr_features["target"]

# Разбиение на обучающую и тестовую выборки
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=TEST_SIZE, random_state=RANDON_STATE
)

# Определение категориальных и числовых признаков
numeric_features = X.select_dtypes(include=["number"]).columns
category_features = X.select_dtypes(exclude=["number"]).columns

# Трансформация данных с помощью пайплайна
preprocessor = ColumnTransformer(
    [
        # ('imputer_before', SimpleImputer(strategy='median')),
        ("num", StandardScaler(), numeric_features),
        (
            "cat",
            OneHotEncoder(handle_unknown="ignore", sparse=False),
            category_features,
        ),
        # ('imputer_after', SimpleImputer(strategy='median')),
    ]
)

# %% [markdown]
# Данные подготовлены для обучения моделей

# %% [markdown]
# ## Обучение моделей

# %% [markdown]
# Рассмотри несколько различных моделей классификации. Для поиска лучших гиперпараметров будем использовать optuna

# %% [markdown]
# ### DecisionTreeClassifier

# %%
# Составляем пайплайн
pipeline = Pipeline(
    [("preprocessor", preprocessor), ("classifier", DecisionTreeClassifier(random_state=RANDON_STATE))]
)


# Функция для оптимизации с помощью Optuna
def objective(trial):
    # Пробуем разные гиперпараметры
    max_depth = trial.suggest_int("max_depth", 2, 10)
    min_samples_split = trial.suggest_int("min_samples_split", 2, 10)
    min_samples_leaf = trial.suggest_int("min_samples_leaf", 1, 10)

    # Настраиваем гиперпараметры в пайплайне
    pipeline.set_params(
        classifier__max_depth=max_depth,
        classifier__min_samples_split=min_samples_split,
        classifier__min_samples_leaf=min_samples_leaf,
    )

    # Оценка качества модели с помощью кросс-валидации
    scores = cross_validate(pipeline, X_train, y_train, cv=5, scoring="roc_auc")
    return scores["test_score"].mean()


# Настройка Optuna
study = optuna.create_study(direction="maximize")
study.optimize(objective, n_trials=50)

# Лучшие параметры
best_params = study.best_params
best_score = study.best_value
print("\nЛучшие гиперпараметры:", best_params)
print("ROC-AUC на кросс-валидации:", best_score)
# Out:
# [I 2025-12-08 18:46:20,011] A new study created in memory with name: no-name-eee5b8f3-654c-45d6-9c99-9997de84e8f2
# [I 2025-12-08 18:46:34,746] Trial 0 finished with value: 0.6210026792187996 and parameters: {'max_depth': 10, 'min_samples_split': 10, 'min_samples_leaf': 4}. Best is trial 0 with value: 0.6210026792187996.
# [I 2025-12-08 18:46:42,855] Trial 1 finished with value: 0.651702851906444 and parameters: {'max_depth': 5, 'min_samples_split': 4, 'min_samples_leaf': 4}. Best is trial 1 with value: 0.651702851906444.
# [I 2025-12-08 18:46:53,984] Trial 2 finished with value: 0.6407209636501461 and parameters: {'max_depth': 7, 'min_samples_split': 5, 'min_samples_leaf': 4}. Best is trial 1 with value: 0.651702851906444.
# [I 2025-12-08 18:47:06,156] Trial 3 finished with value: 0.6246420509021728 and parameters: {'max_depth': 9, 'min_samples_split': 9, 'min_samples_leaf': 7}. Best is trial 1 with value: 0.651702851906444.
# [I 2025-12-08 18:47:17,167] Trial 4 finished with value: 0.6308985979613623 and parameters: {'max_depth': 8, 'min_samples_split': 4, 'min_samples_leaf': 7}. Best is trial 1 with value: 0.651702851906444.
# [I 2025-12-08 18:47:28,016] Trial 5 finished with value: 0.6407209636501461 and parameters: {'max_depth': 7, 'min_samples_split': 4, 'min_samples_leaf': 4}. Best is trial 1 with value: 0.651702851906444.
# [I 2025-12-08 18:47:36,285] Trial 6 finished with value: 0.6472364165161894 and parameters: {'max_depth': 5, 'min_samples_split': 10, 'min_samples_leaf': 8}. Best is trial 1 with value: 0.651702851906444.
# [I 2025-12-08 18:47:50,680] Trial 7 finished with value: 0.6171244346105371 and parameters: {'max_depth': 10, 'min_samples_split': 5, 'min_samples_leaf': 10}. Best is trial 1 with value: 0.651702851906444.
# [I 2025-12-08 18:48:03,776] Trial 8 finished with value: 0.6275804621695625 and parameters: {'max_depth': 8, 'min_samples_split': 2, 'min_samples_leaf': 5}. Best is trial 1 with value: 0.651702851906444.
# [I 2025-12-08 18:48:15,454] Trial 9 finished with value: 0.6391732541725256 and parameters: {'max_depth': 8, 'min_samples_split': 2, 'min_samples_leaf': 10}. Best is trial 1 with value: 0.651702851906444.
# [I 2025-12-08 18:48:19,996] Trial 10 finished with value: 0.5916629390937558 and parameters: {'max_depth': 2, 'min_samples_split': 7, 'min_samples_leaf': 1}. Best is trial 1 with value: 0.651702851906444.
# [I 2025-12-08 18:48:26,956] Trial 11 finished with value: 0.650819475047782 and parameters: {'max_depth': 4, 'min_samples_split': 8, 'min_samples_leaf': 8}. Best is trial 1 with value: 0.651702851906444.
# [I 2025-12-08 18:48:33,734] Trial 12 finished with value: 0.649672989659161 and parameters: {'max_depth': 4, 'min_samples_split': 7, 'min_samples_leaf': 2}. Best is trial 1 with value: 0.651702851906444.
# [I 2025-12-08 18:48:39,465] Trial 13 finished with value: 0.6266223757965246 and parameters: {'max_depth': 3, 'min_samples_split': 8, 'min_samples_leaf': 8}. Best is trial 1 with value: 0.651702851906444.
# [I 2025-12-08 18:48:47,963] Trial 14 finished with value: 0.6472940706910396 and parameters: {'max_depth': 5, 'min_samples_split': 6, 'min_samples_leaf': 6}. Best is trial 1 with value: 0.651702851906444.
# [I 2025-12-08 18:48:55,929] Trial 15 finished with value: 0.6478614962314699 and parameters: {'max_depth': 5, 'min_samples_split': 3, 'min_samples_leaf': 2}. Best is trial 1 with value: 0.651702851906444.
# [I 2025-12-08 18:49:01,377] Trial 16 finished with value: 0.6266290877838807 and parameters: {'max_depth': 3, 'min_samples_split': 8, 'min_samples_leaf': 9}. Best is trial 1 with value: 0.651702851906444.
# [I 2025-12-08 18:49:10,157] Trial 17 finished with value: 0.6487006311094106 and parameters: {'max_depth': 6, 'min_samples_split': 6, 'min_samples_leaf': 6}. Best is trial 1 with value: 0.651702851906444.
# [I 2025-12-08 18:49:17,023] Trial 18 finished with value: 0.6496501942304043 and parameters: {'max_depth': 4, 'min_samples_split': 8, 'min_samples_leaf': 3}. Best is trial 1 with value: 0.651702851906444.
# [I 2025-12-08 18:49:21,234] Trial 19 finished with value: 0.5921516565934826 and parameters: {'max_depth': 2, 'min_samples_split': 4, 'min_samples_leaf': 5}. Best is trial 1 with value: 0.651702851906444.
# [I 2025-12-08 18:49:30,163] Trial 20 finished with value: 0.650010510243767 and parameters: {'max_depth': 6, 'min_samples_split': 7, 'min_samples_leaf': 8}. Best is trial 1 with value: 0.651702851906444.
# [I 2025-12-08 18:49:39,080] Trial 21 finished with value: 0.650010510243767 and parameters: {'max_depth': 6, 'min_samples_split': 7, 'min_samples_leaf': 8}. Best is trial 1 with value: 0.651702851906444.
# [I 2025-12-08 18:49:45,744] Trial 22 finished with value: 0.65258407193664 and parameters: {'max_depth': 4, 'min_samples_split': 9, 'min_samples_leaf': 9}. Best is trial 22 with value: 0.65258407193664.
# [I 2025-12-08 18:49:52,361] Trial 23 finished with value: 0.65258407193664 and parameters: {'max_depth': 4, 'min_samples_split': 9, 'min_samples_leaf': 9}. Best is trial 22 with value: 0.65258407193664.
# [I 2025-12-08 18:49:57,745] Trial 24 finished with value: 0.6266290877838807 and parameters: {'max_depth': 3, 'min_samples_split': 9, 'min_samples_leaf': 9}. Best is trial 22 with value: 0.65258407193664.
# [I 2025-12-08 18:50:04,588] Trial 25 finished with value: 0.65258407193664 and parameters: {'max_depth': 4, 'min_samples_split': 9, 'min_samples_leaf': 9}. Best is trial 22 with value: 0.65258407193664.
# [I 2025-12-08 18:50:11,211] Trial 26 finished with value: 0.65258407193664 and parameters: {'max_depth': 4, 'min_samples_split': 9, 'min_samples_leaf': 9}. Best is trial 22 with value: 0.65258407193664.
# [I 2025-12-08 18:50:16,594] Trial 27 finished with value: 0.6266147773202723 and parameters: {'max_depth': 3, 'min_samples_split': 10, 'min_samples_leaf': 10}. Best is trial 22 with value: 0.65258407193664.
# [I 2025-12-08 18:50:20,632] Trial 28 finished with value: 0.5921516565934826 and parameters: {'max_depth': 2, 'min_samples_split': 9, 'min_samples_leaf': 7}. Best is trial 22 with value: 0.65258407193664.
# [I 2025-12-08 18:50:27,646] Trial 29 finished with value: 0.65258407193664 and parameters: {'max_depth': 4, 'min_samples_split': 10, 'min_samples_leaf': 9}. Best is trial 22 with value: 0.65258407193664.
# [I 2025-12-08 18:50:33,208] Trial 30 finished with value: 0.6266147773202723 and parameters: {'max_depth': 3, 'min_samples_split': 10, 'min_samples_leaf': 10}. Best is trial 22 with value: 0.65258407193664.
# [I 2025-12-08 18:50:39,857] Trial 31 finished with value: 0.65258407193664 and parameters: {'max_depth': 4, 'min_samples_split': 9, 'min_samples_leaf': 9}. Best is trial 22 with value: 0.65258407193664.
# [I 2025-12-08 18:50:47,655] Trial 32 finished with value: 0.6472994622713467 and parameters: {'max_depth': 5, 'min_samples_split': 9, 'min_samples_leaf': 9}. Best is trial 22 with value: 0.65258407193664.
# [I 2025-12-08 18:50:55,516] Trial 33 finished with value: 0.65258407193664 and parameters: {'max_depth': 4, 'min_samples_split': 8, 'min_samples_leaf': 9}. Best is trial 22 with value: 0.65258407193664.
# [I 2025-12-08 18:51:03,392] Trial 34 finished with value: 0.6473106498986556 and parameters: {'max_depth': 5, 'min_samples_split': 9, 'min_samples_leaf': 7}. Best is trial 22 with value: 0.65258407193664.
# [I 2025-12-08 18:51:12,986] Trial 35 finished with value: 0.6480748317968311 and parameters: {'max_depth': 6, 'min_samples_split': 10, 'min_samples_leaf': 10}. Best is trial 22 with value: 0.65258407193664.
# [I 2025-12-08 18:51:18,366] Trial 36 finished with value: 0.6266446646601977 and parameters: {'max_depth': 3, 'min_samples_split': 9, 'min_samples_leaf': 7}. Best is trial 22 with value: 0.65258407193664.
# [I 2025-12-08 18:51:25,348] Trial 37 finished with value: 0.650819475047782 and parameters: {'max_depth': 4, 'min_samples_split': 8, 'min_samples_leaf': 8}. Best is trial 22 with value: 0.65258407193664.
# [I 2025-12-08 18:51:33,502] Trial 38 finished with value: 0.6472994622713467 and parameters: {'max_depth': 5, 'min_samples_split': 10, 'min_samples_leaf': 9}. Best is trial 22 with value: 0.65258407193664.
# [I 2025-12-08 18:51:44,279] Trial 39 finished with value: 0.6439644341047573 and parameters: {'max_depth': 7, 'min_samples_split': 9, 'min_samples_leaf': 10}. Best is trial 22 with value: 0.65258407193664.
# [I 2025-12-08 18:51:48,825] Trial 40 finished with value: 0.5921516565934826 and parameters: {'max_depth': 2, 'min_samples_split': 6, 'min_samples_leaf': 6}. Best is trial 22 with value: 0.65258407193664.
# [I 2025-12-08 18:51:55,685] Trial 41 finished with value: 0.65258407193664 and parameters: {'max_depth': 4, 'min_samples_split': 10, 'min_samples_leaf': 9}. Best is trial 22 with value: 0.65258407193664.
# [I 2025-12-08 18:52:02,231] Trial 42 finished with value: 0.650819475047782 and parameters: {'max_depth': 4, 'min_samples_split': 10, 'min_samples_leaf': 8}. Best is trial 22 with value: 0.65258407193664.
# [I 2025-12-08 18:52:10,036] Trial 43 finished with value: 0.6472994622713467 and parameters: {'max_depth': 5, 'min_samples_split': 9, 'min_samples_leaf': 9}. Best is trial 22 with value: 0.65258407193664.
# [I 2025-12-08 18:52:15,367] Trial 44 finished with value: 0.6266147773202723 and parameters: {'max_depth': 3, 'min_samples_split': 10, 'min_samples_leaf': 10}. Best is trial 22 with value: 0.65258407193664.
# [I 2025-12-08 18:52:22,041] Trial 45 finished with value: 0.65258407193664 and parameters: {'max_depth': 4, 'min_samples_split': 8, 'min_samples_leaf': 9}. Best is trial 22 with value: 0.65258407193664.
# [I 2025-12-08 18:52:28,567] Trial 46 finished with value: 0.6508412671635246 and parameters: {'max_depth': 4, 'min_samples_split': 10, 'min_samples_leaf': 7}. Best is trial 22 with value: 0.65258407193664.
# [I 2025-12-08 18:52:36,407] Trial 47 finished with value: 0.6489761946611023 and parameters: {'max_depth': 5, 'min_samples_split': 5, 'min_samples_leaf': 10}. Best is trial 22 with value: 0.65258407193664.
# [I 2025-12-08 18:52:41,673] Trial 48 finished with value: 0.6266223757965246 and parameters: {'max_depth': 3, 'min_samples_split': 9, 'min_samples_leaf': 8}. Best is trial 22 with value: 0.65258407193664.
# [I 2025-12-08 18:52:55,093] Trial 49 finished with value: 0.6160664773605461 and parameters: {'max_depth': 10, 'min_samples_split': 7, 'min_samples_leaf': 8}. Best is trial 22 with value: 0.65258407193664.
# Лучшие гиперпараметры: {'max_depth': 4, 'min_samples_split': 9, 'min_samples_leaf': 9}
# ROC-AUC на кросс-валидации: 0.65258407193664

# %% [markdown]
# ### Perceptron

# %%
# Составляем пайплайн
pipeline = Pipeline(
    [("preprocessor", preprocessor), ("classifier", Perceptron(tol=1e-3, random_state=RANDON_STATE))]
)


# Функция для оптимизации с помощью Optuna
def objective(trial):
    # Пробуем разные гиперпараметры
    penalty = trial.suggest_categorical("penalty", ["l1", "l2", "elasticnet"])
    alpha = trial.suggest_float("alpha", 0.0001, 1.0)
    eta0 = trial.suggest_float("eta0", 0.001, 1.0)

    # Настраиваем гиперпараметры в пайплайне
    pipeline.set_params(
        classifier__penalty=penalty, classifier__alpha=alpha, classifier__eta0=eta0
    )

    # Оценка качества модели с помощью кросс-валидации
    scores = cross_validate(pipeline, X_train, y_train, cv=5, scoring="roc_auc")
    return scores["test_score"].mean()


# Настройка Optuna
study = optuna.create_study(direction="maximize")  # Максимизируем ROC-AUC
study.optimize(objective, n_trials=50)  # Количество испытаний

# Лучшие параметры
best_params = study.best_params
best_score = study.best_value
print("\nЛучшие гиперпараметры:", best_params)
print("ROC-AUC на кросс-валидации:", best_score)
# Out:
# [I 2025-12-08 18:52:55,235] A new study created in memory with name: no-name-e79d739f-8a99-43b8-a5ce-3a87b59bdc86
# [I 2025-12-08 18:52:59,629] Trial 0 finished with value: 0.5 and parameters: {'penalty': 'l1', 'alpha': 0.5343570666725536, 'eta0': 0.5874782327811913}. Best is trial 0 with value: 0.5.
# [I 2025-12-08 18:53:04,230] Trial 1 finished with value: 0.5 and parameters: {'penalty': 'l1', 'alpha': 0.4880353863771341, 'eta0': 0.3980025641144667}. Best is trial 0 with value: 0.5.
# [I 2025-12-08 18:53:07,295] Trial 2 finished with value: 0.49443055546392883 and parameters: {'penalty': 'l2', 'alpha': 0.43703648642314363, 'eta0': 0.9001495586391999}. Best is trial 0 with value: 0.5.
# [I 2025-12-08 18:53:10,273] Trial 3 finished with value: 0.536958687104251 and parameters: {'penalty': 'l2', 'alpha': 0.11614987319971035, 'eta0': 0.8340962296938669}. Best is trial 3 with value: 0.536958687104251.
# [I 2025-12-08 18:53:14,799] Trial 4 finished with value: 0.5 and parameters: {'penalty': 'l1', 'alpha': 0.8099470862191364, 'eta0': 0.2949510517686049}. Best is trial 3 with value: 0.536958687104251.
# [I 2025-12-08 18:53:19,972] Trial 5 finished with value: 0.5 and parameters: {'penalty': 'elasticnet', 'alpha': 0.080103129107534, 'eta0': 0.4784308202642688}. Best is trial 3 with value: 0.536958687104251.
# [I 2025-12-08 18:53:22,943] Trial 6 finished with value: 0.527461820896493 and parameters: {'penalty': 'l2', 'alpha': 0.3266023479351801, 'eta0': 0.8889311556936322}. Best is trial 3 with value: 0.536958687104251.
# [I 2025-12-08 18:53:27,362] Trial 7 finished with value: 0.5 and parameters: {'penalty': 'l1', 'alpha': 0.9197338692919124, 'eta0': 0.32394052672606616}. Best is trial 3 with value: 0.536958687104251.
# [I 2025-12-08 18:53:31,806] Trial 8 finished with value: 0.5 and parameters: {'penalty': 'l1', 'alpha': 0.33610349126056926, 'eta0': 0.09869330412039985}. Best is trial 3 with value: 0.536958687104251.
# [I 2025-12-08 18:53:34,669] Trial 9 finished with value: 0.5189704579097036 and parameters: {'penalty': 'l2', 'alpha': 0.9870127063157382, 'eta0': 0.38422716537208856}. Best is trial 3 with value: 0.536958687104251.
# [I 2025-12-08 18:53:40,335] Trial 10 finished with value: 0.5 and parameters: {'penalty': 'elasticnet', 'alpha': 0.0415553653709248, 'eta0': 0.7125385185579974}. Best is trial 3 with value: 0.536958687104251.
# [I 2025-12-08 18:53:43,256] Trial 11 finished with value: 0.5416622175330265 and parameters: {'penalty': 'l2', 'alpha': 0.20637900339052898, 'eta0': 0.9606976190487706}. Best is trial 11 with value: 0.5416622175330265.
# [I 2025-12-08 18:53:46,121] Trial 12 finished with value: 0.5411976168508208 and parameters: {'penalty': 'l2', 'alpha': 0.1644085277552776, 'eta0': 0.9890328353996817}. Best is trial 11 with value: 0.5416622175330265.
# [I 2025-12-08 18:53:49,175] Trial 13 finished with value: 0.5409271709808734 and parameters: {'penalty': 'l2', 'alpha': 0.22771207331510393, 'eta0': 0.9936014988434386}. Best is trial 11 with value: 0.5416622175330265.
# [I 2025-12-08 18:53:52,484] Trial 14 finished with value: 0.5321989230426325 and parameters: {'penalty': 'l2', 'alpha': 0.6584628754310085, 'eta0': 0.6957036595216334}. Best is trial 11 with value: 0.5416622175330265.
# [I 2025-12-08 18:53:55,617] Trial 15 finished with value: 0.5443032122666345 and parameters: {'penalty': 'l2', 'alpha': 0.16246808108130328, 'eta0': 0.9919509970641339}. Best is trial 15 with value: 0.5443032122666345.
# [I 2025-12-08 18:53:58,585] Trial 16 finished with value: 0.5426742432703026 and parameters: {'penalty': 'l2', 'alpha': 0.2288417532418287, 'eta0': 0.746898955432465}. Best is trial 15 with value: 0.5443032122666345.
# [I 2025-12-08 18:54:03,216] Trial 17 finished with value: 0.5 and parameters: {'penalty': 'elasticnet', 'alpha': 0.3233005565675253, 'eta0': 0.7850761464724006}. Best is trial 15 with value: 0.5443032122666345.
# [I 2025-12-08 18:54:06,077] Trial 18 finished with value: 0.5086923966780011 and parameters: {'penalty': 'l2', 'alpha': 0.024270397814411315, 'eta0': 0.6062112172733407}. Best is trial 15 with value: 0.5443032122666345.
# [I 2025-12-08 18:54:08,975] Trial 19 finished with value: 0.5297593056005836 and parameters: {'penalty': 'l2', 'alpha': 0.6518234678473458, 'eta0': 0.7508389792315066}. Best is trial 15 with value: 0.5443032122666345.
# [I 2025-12-08 18:54:13,369] Trial 20 finished with value: 0.5 and parameters: {'penalty': 'elasticnet', 'alpha': 0.28498439835832756, 'eta0': 0.6185737354674655}. Best is trial 15 with value: 0.5443032122666345.
# [I 2025-12-08 18:54:16,380] Trial 21 finished with value: 0.5422125199955768 and parameters: {'penalty': 'l2', 'alpha': 0.19734648945945882, 'eta0': 0.8870346467625223}. Best is trial 15 with value: 0.5443032122666345.
# [I 2025-12-08 18:54:19,302] Trial 22 finished with value: 0.5019899064354656 and parameters: {'penalty': 'l2', 'alpha': 0.4026680420669084, 'eta0': 0.8562352064723855}. Best is trial 15 with value: 0.5443032122666345.
# [I 2025-12-08 18:54:22,364] Trial 23 finished with value: 0.48699890012547103 and parameters: {'penalty': 'l2', 'alpha': 0.1592453523359989, 'eta0': 0.8030444595324564}. Best is trial 15 with value: 0.5443032122666345.
# [I 2025-12-08 18:54:25,295] Trial 24 finished with value: 0.5416363984212135 and parameters: {'penalty': 'l2', 'alpha': 0.23976298837908494, 'eta0': 0.8871158221656705}. Best is trial 15 with value: 0.5443032122666345.
# [I 2025-12-08 18:54:28,281] Trial 25 finished with value: 0.47937218974184503 and parameters: {'penalty': 'l2', 'alpha': 0.12743642747172929, 'eta0': 0.6876411128990699}. Best is trial 15 with value: 0.5443032122666345.
# [I 2025-12-08 18:54:31,209] Trial 26 finished with value: 0.5223026675717296 and parameters: {'penalty': 'l2', 'alpha': 0.5793598735221203, 'eta0': 0.9280837831560204}. Best is trial 15 with value: 0.5443032122666345.
# [I 2025-12-08 18:54:34,055] Trial 27 finished with value: 0.5417637828505494 and parameters: {'penalty': 'l2', 'alpha': 0.41103456039239716, 'eta0': 0.5220994225739776}. Best is trial 15 with value: 0.5443032122666345.
# [I 2025-12-08 18:54:40,100] Trial 28 finished with value: 0.49672011772572533 and parameters: {'penalty': 'elasticnet', 'alpha': 0.003751796468719648, 'eta0': 0.06441375355282986}. Best is trial 15 with value: 0.5443032122666345.
# [I 2025-12-08 18:54:43,043] Trial 29 finished with value: 0.5421775012298928 and parameters: {'penalty': 'l2', 'alpha': 0.2688139430986448, 'eta0': 0.6520043373793687}. Best is trial 15 with value: 0.5443032122666345.
# [I 2025-12-08 18:54:47,436] Trial 30 finished with value: 0.5 and parameters: {'penalty': 'l1', 'alpha': 0.19739149678179266, 'eta0': 0.7639454079953109}. Best is trial 15 with value: 0.5443032122666345.
# [I 2025-12-08 18:54:50,312] Trial 31 finished with value: 0.5421725474945998 and parameters: {'penalty': 'l2', 'alpha': 0.26936069965174325, 'eta0': 0.6510533362890473}. Best is trial 15 with value: 0.5443032122666345.
# [I 2025-12-08 18:54:53,033] Trial 32 finished with value: 0.4927591665504315 and parameters: {'penalty': 'l2', 'alpha': 0.09743816616469339, 'eta0': 0.5048430797666923}. Best is trial 15 with value: 0.5443032122666345.
# [I 2025-12-08 18:54:55,891] Trial 33 finished with value: 0.5040356273113504 and parameters: {'penalty': 'l2', 'alpha': 0.3765950003305517, 'eta0': 0.8385706608382162}. Best is trial 15 with value: 0.5443032122666345.
# [I 2025-12-08 18:54:58,878] Trial 34 finished with value: 0.5267642238370522 and parameters: {'penalty': 'l2', 'alpha': 0.48791013450276904, 'eta0': 0.5699972492972205}. Best is trial 15 with value: 0.5443032122666345.
# [I 2025-12-08 18:55:01,744] Trial 35 finished with value: 0.5433329486972874 and parameters: {'penalty': 'l2', 'alpha': 0.16466457879265994, 'eta0': 0.9262347636911312}. Best is trial 15 with value: 0.5443032122666345.
# [I 2025-12-08 18:55:06,213] Trial 36 finished with value: 0.5 and parameters: {'penalty': 'l1', 'alpha': 0.07651136613387687, 'eta0': 0.9348948922927884}. Best is trial 15 with value: 0.5443032122666345.
# [I 2025-12-08 18:55:09,233] Trial 37 finished with value: 0.4871413587929017 and parameters: {'penalty': 'l2', 'alpha': 0.14426279905630013, 'eta0': 0.8942990760889425}. Best is trial 15 with value: 0.5443032122666345.
# [I 2025-12-08 18:55:12,212] Trial 38 finished with value: 0.49082187121843274 and parameters: {'penalty': 'l2', 'alpha': 0.4945528697487238, 'eta0': 0.8256884100138735}. Best is trial 15 with value: 0.5443032122666345.
# [I 2025-12-08 18:55:16,672] Trial 39 finished with value: 0.5 and parameters: {'penalty': 'l1', 'alpha': 0.0759546383432324, 'eta0': 0.16919799320424828}. Best is trial 15 with value: 0.5443032122666345.
# [I 2025-12-08 18:55:19,645] Trial 40 finished with value: 0.5424812449186417 and parameters: {'penalty': 'l2', 'alpha': 0.18558479487671453, 'eta0': 0.9278443713987004}. Best is trial 15 with value: 0.5443032122666345.
# [I 2025-12-08 18:55:22,519] Trial 41 finished with value: 0.5429263948760431 and parameters: {'penalty': 'l2', 'alpha': 0.1776521007649406, 'eta0': 0.9518611767747213}. Best is trial 15 with value: 0.5443032122666345.
# [I 2025-12-08 18:55:25,437] Trial 42 finished with value: 0.5276286742068683 and parameters: {'penalty': 'l2', 'alpha': 0.3118794834534089, 'eta0': 0.9424761025677107}. Best is trial 15 with value: 0.5443032122666345.
# [I 2025-12-08 18:55:28,442] Trial 43 finished with value: 0.48706157871911443 and parameters: {'penalty': 'l2', 'alpha': 0.13077459441053402, 'eta0': 0.9812299145695295}. Best is trial 15 with value: 0.5443032122666345.
# [I 2025-12-08 18:55:31,317] Trial 44 finished with value: 0.5419707490471865 and parameters: {'penalty': 'l2', 'alpha': 0.18653896037097953, 'eta0': 0.8518532549696672}. Best is trial 15 with value: 0.5443032122666345.
# [I 2025-12-08 18:55:35,743] Trial 45 finished with value: 0.5 and parameters: {'penalty': 'elasticnet', 'alpha': 0.24340823355810867, 'eta0': 0.9313090598427776}. Best is trial 15 with value: 0.5443032122666345.
# [I 2025-12-08 18:55:38,478] Trial 46 finished with value: 0.48847805053493276 and parameters: {'penalty': 'l2', 'alpha': 0.8092495634488606, 'eta0': 0.7426806393440475}. Best is trial 15 with value: 0.5443032122666345.
# [I 2025-12-08 18:55:41,425] Trial 47 finished with value: 0.5369155063577452 and parameters: {'penalty': 'l2', 'alpha': 0.0948698304597754, 'eta0': 0.9914348058521171}. Best is trial 15 with value: 0.5443032122666345.
# [I 2025-12-08 18:55:45,854] Trial 48 finished with value: 0.5 and parameters: {'penalty': 'l1', 'alpha': 0.3651479950562283, 'eta0': 0.4259767395219618}. Best is trial 15 with value: 0.5443032122666345.
# [I 2025-12-08 18:55:48,637] Trial 49 finished with value: 0.49228062354784674 and parameters: {'penalty': 'l2', 'alpha': 0.06167646065406082, 'eta0': 0.8119731532314343}. Best is trial 15 with value: 0.5443032122666345.
# Лучшие гиперпараметры: {'penalty': 'l2', 'alpha': 0.16246808108130328, 'eta0': 0.9919509970641339}
# ROC-AUC на кросс-валидации: 0.5443032122666345

# %% [markdown]
# ### CatBoost

# %%
# Составляем пайплайн
pipeline = Pipeline(
    [
        ("classifier", CatBoostClassifier(task_type="CPU", verbose=0, random_state=RANDON_STATE)),
    ]
)


# Функция для оптимизации с помощью Optuna
def objective(trial):
    # Пробуем разные гиперпараметры
    iterations = trial.suggest_int("iterations", 100, 500)
    learning_rate = trial.suggest_float("learning_rate", 0.01, 0.3)
    depth = trial.suggest_int("depth", 4, 10)
    l2_leaf_reg = trial.suggest_float("l2_leaf_reg", 1, 10)
    random_strength = trial.suggest_float('random_strength', 0.1, 1.0)
    bagging_temperature = trial.suggest_float('bagging_temperature', 0.0, 1.0)

    # Настраиваем гиперпараметры в пайплайне
    pipeline.set_params(
        classifier__iterations=iterations,
        classifier__learning_rate=learning_rate,
        classifier__depth=depth,
        classifier__l2_leaf_reg=l2_leaf_reg,
        classifier__random_strength=random_strength,
        classifier__bagging_temperature=bagging_temperature,
    )

    # Оценка качества модели с помощью кросс-валидации
    scores = cross_validate(pipeline, X_train, y_train, cv=5, scoring="roc_auc")
    return scores["test_score"].mean()


# Настройка Optuna
study = optuna.create_study(direction="maximize")
study.optimize(objective, n_trials=50)

# Лучшие параметры
best_params = study.best_params
best_score = study.best_value
print("\nЛучшие гиперпараметры:", best_params)
print("ROC-AUC на кросс-валидации:", best_score)
# Out:
# [I 2025-12-08 18:55:48,746] A new study created in memory with name: no-name-ab3702c1-7e86-45c5-9aef-f5bb8f58a6fe
# [I 2025-12-08 18:56:01,377] Trial 0 finished with value: 0.6192041130178902 and parameters: {'iterations': 471, 'learning_rate': 0.26522862123921986, 'depth': 8, 'l2_leaf_reg': 8.249511326267118, 'random_strength': 0.3213387846732257, 'bagging_temperature': 0.18184591107191783}. Best is trial 0 with value: 0.6192041130178902.
# [I 2025-12-08 18:56:34,681] Trial 1 finished with value: 0.6686081205445834 and parameters: {'iterations': 463, 'learning_rate': 0.039199597024914795, 'depth': 10, 'l2_leaf_reg': 3.2950090273264063, 'random_strength': 0.7546572536337973, 'bagging_temperature': 0.5837127578109053}. Best is trial 1 with value: 0.6686081205445834.
# [I 2025-12-08 18:56:36,259] Trial 2 finished with value: 0.7146462887706851 and parameters: {'iterations': 131, 'learning_rate': 0.159181160523522, 'depth': 6, 'l2_leaf_reg': 9.389798125290941, 'random_strength': 0.10697581014563372, 'bagging_temperature': 0.31790035305533804}. Best is trial 2 with value: 0.7146462887706851.
# [I 2025-12-08 18:56:44,602] Trial 3 finished with value: 0.6554504891141126 and parameters: {'iterations': 494, 'learning_rate': 0.24173299060828118, 'depth': 4, 'l2_leaf_reg': 4.705791726294358, 'random_strength': 0.6096534834912362, 'bagging_temperature': 0.7772777027137654}. Best is trial 2 with value: 0.7146462887706851.
# [I 2025-12-08 18:57:15,359] Trial 4 finished with value: 0.6224290496697666 and parameters: {'iterations': 428, 'learning_rate': 0.16996099584500077, 'depth': 10, 'l2_leaf_reg': 7.697539724860599, 'random_strength': 0.8850447278391289, 'bagging_temperature': 0.967359038611782}. Best is trial 2 with value: 0.7146462887706851.
# [I 2025-12-08 18:57:26,503] Trial 5 finished with value: 0.6698070560353656 and parameters: {'iterations': 395, 'learning_rate': 0.10688891397407624, 'depth': 8, 'l2_leaf_reg': 6.549544895711942, 'random_strength': 0.8276397804068769, 'bagging_temperature': 0.044332784144170856}. Best is trial 2 with value: 0.7146462887706851.
# [I 2025-12-08 18:57:28,096] Trial 6 finished with value: 0.7115725932111168 and parameters: {'iterations': 126, 'learning_rate': 0.032707747850835876, 'depth': 7, 'l2_leaf_reg': 1.365963741906595, 'random_strength': 0.6556232087455344, 'bagging_temperature': 0.713388379460892}. Best is trial 2 with value: 0.7146462887706851.
# [I 2025-12-08 18:57:30,510] Trial 7 finished with value: 0.7149941154022802 and parameters: {'iterations': 186, 'learning_rate': 0.08242428814692546, 'depth': 7, 'l2_leaf_reg': 3.6985705621516605, 'random_strength': 0.8926002666824584, 'bagging_temperature': 0.9843544763289411}. Best is trial 7 with value: 0.7149941154022802.
# [I 2025-12-08 18:57:35,327] Trial 8 finished with value: 0.7004464733095962 and parameters: {'iterations': 288, 'learning_rate': 0.18010180100422507, 'depth': 4, 'l2_leaf_reg': 7.781819023126386, 'random_strength': 0.13033692070910005, 'bagging_temperature': 0.5531555075150151}. Best is trial 7 with value: 0.7149941154022802.
# [I 2025-12-08 18:57:58,163] Trial 9 finished with value: 0.5793505684445608 and parameters: {'iterations': 330, 'learning_rate': 0.23057508702767707, 'depth': 10, 'l2_leaf_reg': 1.4098710473638678, 'random_strength': 0.7563884729329774, 'bagging_temperature': 0.1812010852621586}. Best is trial 7 with value: 0.7149941154022802.
# [I 2025-12-08 18:58:02,881] Trial 10 finished with value: 0.6978996231077242 and parameters: {'iterations': 235, 'learning_rate': 0.09865911449921463, 'depth': 6, 'l2_leaf_reg': 3.717168971775124, 'random_strength': 0.9699032622908019, 'bagging_temperature': 0.9937872500502594}. Best is trial 7 with value: 0.7149941154022802.
# [I 2025-12-08 18:58:04,051] Trial 11 finished with value: 0.7143136816710459 and parameters: {'iterations': 110, 'learning_rate': 0.11042787512074219, 'depth': 6, 'l2_leaf_reg': 9.715581449807468, 'random_strength': 0.4066203163840919, 'bagging_temperature': 0.36056140232402933}. Best is trial 7 with value: 0.7149941154022802.
# [I 2025-12-08 18:58:05,847] Trial 12 finished with value: 0.7149956350975307 and parameters: {'iterations': 190, 'learning_rate': 0.07577042706764481, 'depth': 6, 'l2_leaf_reg': 5.515414384975913, 'random_strength': 0.12731191954716148, 'bagging_temperature': 0.3868007347511577}. Best is trial 12 with value: 0.7149956350975307.
# [I 2025-12-08 18:58:07,724] Trial 13 finished with value: 0.7130778552835446 and parameters: {'iterations': 192, 'learning_rate': 0.058083908011549466, 'depth': 5, 'l2_leaf_reg': 5.392966812311486, 'random_strength': 0.416742344039843, 'bagging_temperature': 0.3779228206570868}. Best is trial 12 with value: 0.7149956350975307.
# [I 2025-12-08 18:58:14,474] Trial 14 finished with value: 0.6997513982767049 and parameters: {'iterations': 201, 'learning_rate': 0.06703985620298256, 'depth': 8, 'l2_leaf_reg': 3.1887890284487996, 'random_strength': 0.27823474915847657, 'bagging_temperature': 0.7024760361963138}. Best is trial 12 with value: 0.7149956350975307.
# [I 2025-12-08 18:58:20,061] Trial 15 finished with value: 0.6906592461557601 and parameters: {'iterations': 256, 'learning_rate': 0.12355750836534797, 'depth': 7, 'l2_leaf_reg': 6.268740010190607, 'random_strength': 0.5217003676261392, 'bagging_temperature': 0.8525960668829653}. Best is trial 12 with value: 0.7149956350975307.
# [I 2025-12-08 18:58:21,779] Trial 16 finished with value: 0.7074511806736232 and parameters: {'iterations': 186, 'learning_rate': 0.011733810362523411, 'depth': 5, 'l2_leaf_reg': 4.3624627361331125, 'random_strength': 0.25043193570086675, 'bagging_temperature': 0.45981240636234216}. Best is trial 12 with value: 0.7149956350975307.
# [I 2025-12-08 18:58:36,844] Trial 17 finished with value: 0.6170145659451924 and parameters: {'iterations': 348, 'learning_rate': 0.1303633976787023, 'depth': 9, 'l2_leaf_reg': 2.448759678639527, 'random_strength': 0.9978228298077054, 'bagging_temperature': 0.6186222730600931}. Best is trial 12 with value: 0.7149956350975307.
# [I 2025-12-08 18:58:38,265] Trial 18 finished with value: 0.7129008863789441 and parameters: {'iterations': 163, 'learning_rate': 0.07614543612863771, 'depth': 5, 'l2_leaf_reg': 6.189601803230388, 'random_strength': 0.4685813430820263, 'bagging_temperature': 0.47034542073147956}. Best is trial 12 with value: 0.7149956350975307.
# [I 2025-12-08 18:58:43,894] Trial 19 finished with value: 0.659660812659195 and parameters: {'iterations': 241, 'learning_rate': 0.19731024312101664, 'depth': 7, 'l2_leaf_reg': 5.1161696460610955, 'random_strength': 0.6546421215945368, 'bagging_temperature': 0.2375028522016423}. Best is trial 12 with value: 0.7149956350975307.
# [I 2025-12-08 18:58:50,964] Trial 20 finished with value: 0.6830466714904228 and parameters: {'iterations': 287, 'learning_rate': 0.08103316615226337, 'depth': 7, 'l2_leaf_reg': 2.23404308291626, 'random_strength': 0.19428464897907358, 'bagging_temperature': 0.054374204459841535}. Best is trial 12 with value: 0.7149956350975307.
# [I 2025-12-08 18:58:52,497] Trial 21 finished with value: 0.7177300636010132 and parameters: {'iterations': 147, 'learning_rate': 0.14375372074179607, 'depth': 6, 'l2_leaf_reg': 9.747995590153126, 'random_strength': 0.11536958928715496, 'bagging_temperature': 0.31746203038845744}. Best is trial 21 with value: 0.7177300636010132.
# [I 2025-12-08 18:58:54,131] Trial 22 finished with value: 0.7134867936911993 and parameters: {'iterations': 155, 'learning_rate': 0.14560111281752713, 'depth': 6, 'l2_leaf_reg': 8.811832185281311, 'random_strength': 0.3421712677146528, 'bagging_temperature': 0.28020056570155893}. Best is trial 21 with value: 0.7177300636010132.
# [I 2025-12-08 18:58:57,766] Trial 23 finished with value: 0.6921868196713122 and parameters: {'iterations': 222, 'learning_rate': 0.208457326942298, 'depth': 5, 'l2_leaf_reg': 7.01076911062153, 'random_strength': 0.20066441389184517, 'bagging_temperature': 0.43159475866091485}. Best is trial 21 with value: 0.7177300636010132.
# [I 2025-12-08 18:58:59,342] Trial 24 finished with value: 0.7155121596825086 and parameters: {'iterations': 160, 'learning_rate': 0.09226822600830595, 'depth': 6, 'l2_leaf_reg': 4.069897172660612, 'random_strength': 0.17628682576738164, 'bagging_temperature': 0.8802973306020514}. Best is trial 21 with value: 0.7177300636010132.
# [I 2025-12-08 18:59:00,881] Trial 25 finished with value: 0.7203498159794346 and parameters: {'iterations': 152, 'learning_rate': 0.1374330649300493, 'depth': 6, 'l2_leaf_reg': 2.405437994554938, 'random_strength': 0.17640110716589594, 'bagging_temperature': 0.8444163231836759}. Best is trial 25 with value: 0.7203498159794346.
# [I 2025-12-08 18:59:02,305] Trial 26 finished with value: 0.7200359527695994 and parameters: {'iterations': 150, 'learning_rate': 0.1473693287374004, 'depth': 5, 'l2_leaf_reg': 2.215655268491382, 'random_strength': 0.2017318540469116, 'bagging_temperature': 0.8812920091952373}. Best is trial 25 with value: 0.7203498159794346.
# [I 2025-12-08 18:59:03,245] Trial 27 finished with value: 0.7186038667722834 and parameters: {'iterations': 115, 'learning_rate': 0.13184422852886568, 'depth': 4, 'l2_leaf_reg': 2.284928302698197, 'random_strength': 0.25364235692834186, 'bagging_temperature': 0.8608215390267102}. Best is trial 25 with value: 0.7203498159794346.
# [I 2025-12-08 18:59:04,107] Trial 28 finished with value: 0.7210238292927503 and parameters: {'iterations': 106, 'learning_rate': 0.1844713085396926, 'depth': 4, 'l2_leaf_reg': 2.519007834977456, 'random_strength': 0.25053566262624655, 'bagging_temperature': 0.8761135590896947}. Best is trial 28 with value: 0.7210238292927503.
# [I 2025-12-08 18:59:04,939] Trial 29 finished with value: 0.7152478279353129 and parameters: {'iterations': 101, 'learning_rate': 0.29526838893825713, 'depth': 4, 'l2_leaf_reg': 1.0505481837192798, 'random_strength': 0.32899830391907725, 'bagging_temperature': 0.786428590952442}. Best is trial 28 with value: 0.7210238292927503.
# [I 2025-12-08 18:59:06,174] Trial 30 finished with value: 0.7224628992125545 and parameters: {'iterations': 141, 'learning_rate': 0.195010563987782, 'depth': 5, 'l2_leaf_reg': 2.713620491854369, 'random_strength': 0.3835732482259895, 'bagging_temperature': 0.9193962659103203}. Best is trial 30 with value: 0.7224628992125545.
# [I 2025-12-08 18:59:07,408] Trial 31 finished with value: 0.717324886144589 and parameters: {'iterations': 139, 'learning_rate': 0.19687861318274996, 'depth': 5, 'l2_leaf_reg': 1.9048546491379847, 'random_strength': 0.3800161512991721, 'bagging_temperature': 0.90588678091043}. Best is trial 30 with value: 0.7224628992125545.
# [I 2025-12-08 18:59:08,804] Trial 32 finished with value: 0.7179281963235784 and parameters: {'iterations': 170, 'learning_rate': 0.22188474453652132, 'depth': 5, 'l2_leaf_reg': 2.9602868932455046, 'random_strength': 0.28903951035916015, 'bagging_temperature': 0.793745746808066}. Best is trial 30 with value: 0.7224628992125545.
# [I 2025-12-08 18:59:09,648] Trial 33 finished with value: 0.7181857208570359 and parameters: {'iterations': 102, 'learning_rate': 0.17383240060549626, 'depth': 4, 'l2_leaf_reg': 2.843546590290304, 'random_strength': 0.20063270521913817, 'bagging_temperature': 0.9202164300724277}. Best is trial 30 with value: 0.7224628992125545.
# [I 2025-12-08 18:59:13,160] Trial 34 finished with value: 0.6585037394713 and parameters: {'iterations': 214, 'learning_rate': 0.2610074040774118, 'depth': 5, 'l2_leaf_reg': 1.929116153931966, 'random_strength': 0.45885845652941093, 'bagging_temperature': 0.6457432989804813}. Best is trial 30 with value: 0.7224628992125545.
# [I 2025-12-08 18:59:14,260] Trial 35 finished with value: 0.7196673687501651 and parameters: {'iterations': 127, 'learning_rate': 0.15865260574622844, 'depth': 4, 'l2_leaf_reg': 2.6524279108538815, 'random_strength': 0.24220765304075995, 'bagging_temperature': 0.7021513617236457}. Best is trial 30 with value: 0.7224628992125545.
# [I 2025-12-08 18:59:20,219] Trial 36 finished with value: 0.6523418091488954 and parameters: {'iterations': 263, 'learning_rate': 0.1909846302644818, 'depth': 5, 'l2_leaf_reg': 1.6650540337788469, 'random_strength': 0.34940299967833366, 'bagging_temperature': 0.8165531178395069}. Best is trial 30 with value: 0.7224628992125545.
# [I 2025-12-08 18:59:21,296] Trial 37 finished with value: 0.7203905718892034 and parameters: {'iterations': 135, 'learning_rate': 0.16602759310232407, 'depth': 4, 'l2_leaf_reg': 3.6115536983584304, 'random_strength': 0.30352095953160346, 'bagging_temperature': 0.9519072239181549}. Best is trial 30 with value: 0.7224628992125545.
# [I 2025-12-08 18:59:22,388] Trial 38 finished with value: 0.7221803772629716 and parameters: {'iterations': 131, 'learning_rate': 0.24667642403805096, 'depth': 4, 'l2_leaf_reg': 3.520156583390022, 'random_strength': 0.5265397069025858, 'bagging_temperature': 0.9505467756976475}. Best is trial 30 with value: 0.7224628992125545.
# [I 2025-12-08 18:59:23,447] Trial 39 finished with value: 0.7203892691530294 and parameters: {'iterations': 128, 'learning_rate': 0.250109534753579, 'depth': 4, 'l2_leaf_reg': 3.513137449764136, 'random_strength': 0.5397316430311558, 'bagging_temperature': 0.9555119916374266}. Best is trial 30 with value: 0.7224628992125545.
# [I 2025-12-08 18:59:29,718] Trial 40 finished with value: 0.6532535173287668 and parameters: {'iterations': 426, 'learning_rate': 0.2775550457482917, 'depth': 4, 'l2_leaf_reg': 4.643415404033805, 'random_strength': 0.47965502686462136, 'bagging_temperature': 0.7452210197188447}. Best is trial 30 with value: 0.7224628992125545.
# [I 2025-12-08 18:59:30,729] Trial 41 finished with value: 0.721816283609219 and parameters: {'iterations': 126, 'learning_rate': 0.2553184216607001, 'depth': 4, 'l2_leaf_reg': 3.4977908914762015, 'random_strength': 0.5663438952544839, 'bagging_temperature': 0.9427704305628323}. Best is trial 30 with value: 0.7224628992125545.
# [I 2025-12-08 18:59:31,758] Trial 42 finished with value: 0.7211065044448927 and parameters: {'iterations': 124, 'learning_rate': 0.22365513091555042, 'depth': 4, 'l2_leaf_reg': 3.9486253699077514, 'random_strength': 0.581982008756441, 'bagging_temperature': 0.9338976133903916}. Best is trial 30 with value: 0.7224628992125545.
# [I 2025-12-08 18:59:33,112] Trial 43 finished with value: 0.7226668976839059 and parameters: {'iterations': 171, 'learning_rate': 0.23569443786825284, 'depth': 4, 'l2_leaf_reg': 4.129959662673075, 'random_strength': 0.604506898657608, 'bagging_temperature': 0.9357543313015935}. Best is trial 43 with value: 0.7226668976839059.
# [I 2025-12-08 18:59:34,373] Trial 44 finished with value: 0.7202380221704295 and parameters: {'iterations': 166, 'learning_rate': 0.2369100275747063, 'depth': 4, 'l2_leaf_reg': 4.2568253288103755, 'random_strength': 0.5829368699869819, 'bagging_temperature': 0.9847777470655898}. Best is trial 43 with value: 0.7226668976839059.
# [I 2025-12-08 18:59:35,705] Trial 45 finished with value: 0.7245604487648294 and parameters: {'iterations': 175, 'learning_rate': 0.21806320760163667, 'depth': 4, 'l2_leaf_reg': 3.9291546607377335, 'random_strength': 0.71866554966954, 'bagging_temperature': 0.9294667245137593}. Best is trial 45 with value: 0.7245604487648294.
# [I 2025-12-08 18:59:37,083] Trial 46 finished with value: 0.7201669184962698 and parameters: {'iterations': 179, 'learning_rate': 0.2561164023140346, 'depth': 4, 'l2_leaf_reg': 4.897697125590479, 'random_strength': 0.7164669801494796, 'bagging_temperature': 0.5361325517800738}. Best is trial 45 with value: 0.7245604487648294.
# [I 2025-12-08 18:59:40,963] Trial 47 finished with value: 0.6785035209414791 and parameters: {'iterations': 204, 'learning_rate': 0.21456818886943674, 'depth': 5, 'l2_leaf_reg': 3.14952383436374, 'random_strength': 0.7327789005038033, 'bagging_temperature': 0.7546931453108777}. Best is trial 45 with value: 0.7245604487648294.
# [I 2025-12-08 18:59:46,675] Trial 48 finished with value: 0.6629585827675512 and parameters: {'iterations': 362, 'learning_rate': 0.2736202707267439, 'depth': 4, 'l2_leaf_reg': 4.507221138427772, 'random_strength': 0.6475138301127792, 'bagging_temperature': 0.823711096328746}. Best is trial 45 with value: 0.7245604487648294.
# [I 2025-12-08 18:59:53,903] Trial 49 finished with value: 0.6617466552567789 and parameters: {'iterations': 479, 'learning_rate': 0.2360869190978022, 'depth': 4, 'l2_leaf_reg': 5.648098857658395, 'random_strength': 0.515263440664362, 'bagging_temperature': 0.9872291944624758}. Best is trial 45 with value: 0.7245604487648294.
# Лучшие гиперпараметры: {'iterations': 175, 'learning_rate': 0.21806320760163667, 'depth': 4, 'l2_leaf_reg': 3.9291546607377335, 'random_strength': 0.71866554966954, 'bagging_temperature': 0.9294667245137593}
# ROC-AUC на кросс-валидации: 0.7245604487648294

# %% [markdown]
# ### Промежуточные выводы

# %% [markdown]
# На кросс-валидации модели показали следующие метрики ROC-AUC:
# - DecisionTreeClassifier: 0.65
# - Perceptron: 0.57
# - CatBoostClassifier: 0.72
#
# Лучшей признана модель CatBoostClassifier

# %% [markdown]
# ## Предсказание на тестовой выборке

# %%
# Обучение финальной модели с лучшими параметрами
clf_final = CatBoostClassifier(verbose=0, **best_params)
clf_final.fit(X_train, y_train)

# Прогноз вероятности
probs_final = clf_final.predict_proba(X_test)[:, 1]
auc_final = roc_auc_score(y_test, probs_final)

print("\nFinal ROC-AUC:", auc_final)
# Out:
# Final ROC-AUC: 0.7823746062744856

# %% [markdown]
# На тестовой выборке модель показала значение метрики ROC-AUC = 0.78, что лучше поставленных требований (0.75)

# %% [markdown]
# ## Общий вывод

# %% [markdown]
# В данной работе был проведен анализ данных о рекламных рассылках и покупках в Интернет-магазине для планирования будущих продаж.
#
# Цель:
# Предсказать вероятность покупки в течение 90 дней

# %% [markdown]
# В ходе предварительной обработки данных было сделано следующее:
# - проведена проверка на наличие пропусков в данных. Пропусков не обнаружено
# - проведена проверка на наличие дубликатов, явные дубликаты удалены
# - проведена проверка на полноту данных после проведения предобработки

# %% [markdown]
# Был проведен исследовательский анализ количественных и категориальных признаков из датасетов.
# - Подавляющее большинство покупок было совершено на сумму в пределах 3777 и в количестве 1 шт
# - Разослано более 9М сообщений, из которых открыто примерно 3М, а покупку совершили всего в 62.5К случаев. Конверсия цепочки событий ['send' -> 'open' -> 'click' -> 'purchase'] составляет [100% -> 33.7% -> 5.34% -> 0.69%]
# - Большинство уведомлений было push уведомлениями

# %% [markdown]
# Были созданы и добавлены новые признаки. Также проведено объединение всех признаков в один датасет.

# %% [markdown]
# Матрица корреляции показала следующие зависимости признака purchase (факт совершения покупки в прошлом):
# - среднюю зависимость (0.5-0.7) от признаков ['click']
# - слабую зависимость (0.2-0.5) от признаков ['hard_bounce', 'price', 'quantity', 'total_days']
# - очень слабую зависимость (0-0.2) от признаков ['hbq_spam', 'open', 'send', 'soft_bounce', 'subscribe', 'unsubscribe', 'complain', 'close', 'recent_activity_days']
#
# Признаки с очень слабой корреляцией были удалены из датасета

# %% [markdown]
# На кросс-валидации модели показали следующие метрики ROC-AUC:
# - DecisionTreeClassifier: 0.65
# - Perceptron: 0.57
# - CatBoostClassifier: 0.72
#
# Лучшей признана модель CatBoostClassifier. Лучшие гиперпараметры: {'iterations': 161, 'learning_rate': 0.21569432286417053, 'depth': 4, 'l2_leaf_reg': 5.090968712687669, 'random_strength': 0.6469160400561126, 'bagging_temperature': 0.16515566522068773}

# %% [markdown]
# На тестовой выборке лучшая модель показала значение метрики ROC-AUC = 0.78, что лучше поставленных требований (0.75)

# %% [markdown]
# ## Project Requirements

# %%
import pkg_resources

installed_packages = {d.project_name: d.version for d in pkg_resources.working_set}

# %%
with open('requirements.txt', 'w') as f:
    for package, version in installed_packages.items():
        f.write(f"{package}=={version}\n")
